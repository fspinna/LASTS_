# %%
import os,sys,inspect
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0,parentdir)

# %%
from datasets import build_synth
from blackboxes import build_resnet
import numpy as np
import time
import keras
from blackbox_wrapper import BlackboxWrapper
from variational_autoencoder import build_vae, plot_history
from utils import reconstruction_accuracy, reconstruction_accuracy_vae, plot_reconstruction_vae
import matplotlib.pyplot as plt
from joblib import dump, load
from ts_generator import PatternClassifier, TimeSeriesGenerator, LocalPattern, PolynomialClassifier, GlobalFeature
import IPython
# Out:
# /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/sklearn/utils/deprecation.py:143: FutureWarning: The sklearn.neighbors.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.neighbors. Anything that cannot be imported from sklearn.neighbors is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/sklearn/utils/deprecation.py:143: FutureWarning: The sklearn.ensemble.bagging module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.ensemble. Anything that cannot be imported from sklearn.ensemble is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/sklearn/utils/deprecation.py:143: FutureWarning: The sklearn.ensemble.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.ensemble. Anything that cannot be imported from sklearn.ensemble is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/sklearn/utils/deprecation.py:143: FutureWarning: The sklearn.ensemble.forest module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.ensemble. Anything that cannot be imported from sklearn.ensemble is now part of the private API.
#   warnings.warn(message, FutureWarning)
# Using TensorFlow backend.
# /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/sklearn/utils/deprecation.py:143: FutureWarning: The sklearn.utils.testing module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.utils. Anything that cannot be imported from sklearn.utils is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/sklearn/utils/deprecation.py:143: FutureWarning: The sklearn.metrics.classification module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.metrics. Anything that cannot be imported from sklearn.metrics is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
# IMPORT DATASET
random_state = 0
dataset_name = "synth04"
dataset_dir = "/trained_models/" + dataset_name + "/"

(X_train, y_train, X_val, y_val, 
 X_test, y_test, X_exp_train, y_exp_train, 
 X_exp_val, y_exp_val, X_exp_test, y_exp_test) = build_synth(path = parentdir + "/datasets/synth04/", 
                                                              random_state = random_state)
# Out:
# DATASET INFO:
# X SHAPE:  (600, 96, 1)
# y SHAPE:  (600,)
#
# CLASSES BALANCE
# 0 :  0.5
# 1 :  0.5
#
# SHAPES:
# BLACKBOX TRAINING SET:  (268, 96, 1)
# BLACKBOX VALIDATION SET:  (68, 96, 1)
# BLACKBOX TEST SET:  (84, 96, 1)
# EXPLANATION TRAINING SET:  (115, 96, 1)
# EXPLANATION VALIDATION SET:  (29, 96, 1)
# EXPLANATION TEST SET:  (36, 96, 1)

# %%
input_shape = X_train.shape[1:]
n_timesteps = input_shape[0]
#n_classes = len(np.unique(y_train))

# %% [markdown]
# ### Blackbox

# %%
pat = load(parentdir + "/trained_models/synth04/synth04_pat.joblib")

# %% [markdown]
# ### VAE

# %%
from variational_autoencoder import rec_loss_sum

# %%
latent_dim = 2

autoencoder_kwargs = {
    "filters": [8, 8, 8, 8, 8, 8, 8, 8],
    "kernel_size": [3, 3, 3, 3, 3, 3, 3, 3],
    "padding": ["same", "same", "same", "same", "same", "same", "same", "same"],
    "activation": ["relu", "relu", "relu", "relu", "relu", "relu", "relu", "relu"],
    "pooling": [1, 1, 1, 1, 1, 1, 1, 1],
    "n_layers": 8,
    "optimizer": "adam",
    "n_layers_residual": None,
    "batch_normalization": False,
    "loss": rec_loss_sum
}

# %%
encoder, decoder, autoencoder = build_vae(input_shape, latent_dim, autoencoder_kwargs)
# Out:
# WARNING:tensorflow:From /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Model: "Encoder"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 96, 1)        0
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 96, 8)        32          input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 96, 8)        32          conv1d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 96, 8)        0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_1 (MaxPooling1D)  (None, 96, 8)        0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 96, 8)        200         max_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 96, 8)        32          conv1d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 96, 8)        0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_2 (MaxPooling1D)  (None, 96, 8)        0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 96, 8)        200         max_pooling1d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 96, 8)        32          conv1d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 96, 8)        0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_3 (MaxPooling1D)  (None, 96, 8)        0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 96, 8)        200         max_pooling1d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 96, 8)        32          conv1d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 96, 8)        0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_4 (MaxPooling1D)  (None, 96, 8)        0           activation_4[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 96, 8)        200         max_pooling1d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 96, 8)        32          conv1d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 96, 8)        0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_5 (MaxPooling1D)  (None, 96, 8)        0           activation_5[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 96, 8)        200         max_pooling1d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 96, 8)        32          conv1d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 96, 8)        0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_6 (MaxPooling1D)  (None, 96, 8)        0           activation_6[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 96, 8)        200         max_pooling1d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 96, 8)        32          conv1d_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 96, 8)        0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_7 (MaxPooling1D)  (None, 96, 8)        0           activation_7[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 96, 8)        200         max_pooling1d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 96, 8)        32          conv1d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 96, 8)        0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_8 (MaxPooling1D)  (None, 96, 8)        0           activation_8[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 96, 1)        9           max_pooling1d_8[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 96)           0           conv1d_9[0][0]
# __________________________________________________________________________________________________
# z_mean (Dense)                  (None, 2)            194         flatten_1[0][0]
# __________________________________________________________________________________________________
# z_log_var (Dense)               (None, 2)            194         flatten_1[0][0]
# __________________________________________________________________________________________________
# kl_divergence_layer_1 (KLDiverg [(None, 2), (None, 2 0           z_mean[0][0]
#                                                                  z_log_var[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 2)            0           kl_divergence_layer_1[0][1]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, 2)            0
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 2)            0           lambda_1[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 2)            0           kl_divergence_layer_1[0][0]
#                                                                  multiply_1[0][0]
# ==================================================================================================
# Total params: 2,085
# Trainable params: 1,957
# Non-trainable params: 128
# __________________________________________________________________________________________________
# Model: "Decoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# z_sampling (InputLayer)      (None, 2)                 0
# _________________________________________________________________
# dense_1 (Dense)              (None, 96)                288
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 96, 1)             0
# _________________________________________________________________
# conv1d_10 (Conv1D)           (None, 96, 8)             32
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 96, 8)             32
# _________________________________________________________________
# activation_9 (Activation)    (None, 96, 8)             0
# _________________________________________________________________
# up_sampling1d_1 (UpSampling1 (None, 96, 8)             0
# _________________________________________________________________
# conv1d_11 (Conv1D)           (None, 96, 8)             200
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 96, 8)             32
# _________________________________________________________________
# activation_10 (Activation)   (None, 96, 8)             0
# _________________________________________________________________
# up_sampling1d_2 (UpSampling1 (None, 96, 8)             0
# _________________________________________________________________
# conv1d_12 (Conv1D)           (None, 96, 8)             200
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 96, 8)             32
# _________________________________________________________________
# activation_11 (Activation)   (None, 96, 8)             0
# _________________________________________________________________
# up_sampling1d_3 (UpSampling1 (None, 96, 8)             0
# _________________________________________________________________
# conv1d_13 (Conv1D)           (None, 96, 8)             200
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 96, 8)             32
# _________________________________________________________________
# activation_12 (Activation)   (None, 96, 8)             0
# _________________________________________________________________
# up_sampling1d_4 (UpSampling1 (None, 96, 8)             0
# _________________________________________________________________
# conv1d_14 (Conv1D)           (None, 96, 8)             200
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 96, 8)             32
# _________________________________________________________________
# activation_13 (Activation)   (None, 96, 8)             0
# _________________________________________________________________
# up_sampling1d_5 (UpSampling1 (None, 96, 8)             0
# _________________________________________________________________
# conv1d_15 (Conv1D)           (None, 96, 8)             200
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 96, 8)             32
# _________________________________________________________________
# activation_14 (Activation)   (None, 96, 8)             0
# _________________________________________________________________
# up_sampling1d_6 (UpSampling1 (None, 96, 8)             0
# _________________________________________________________________
# conv1d_16 (Conv1D)           (None, 96, 8)             200
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 96, 8)             32
# _________________________________________________________________
# activation_15 (Activation)   (None, 96, 8)             0
# _________________________________________________________________
# up_sampling1d_7 (UpSampling1 (None, 96, 8)             0
# _________________________________________________________________
# conv1d_17 (Conv1D)           (None, 96, 8)             200
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 96, 8)             32
# _________________________________________________________________
# activation_16 (Activation)   (None, 96, 8)             0
# _________________________________________________________________
# up_sampling1d_8 (UpSampling1 (None, 96, 8)             0
# _________________________________________________________________
# conv1d_18 (Conv1D)           (None, 96, 1)             9
# =================================================================
# Total params: 1,985
# Trainable params: 1,857
# Non-trainable params: 128
# _________________________________________________________________
# Model: "VAE"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            (None, 96, 1)        0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            (None, 2)            0
# __________________________________________________________________________________________________
# Encoder (Model)                 (None, 2)            2085        input_3[0][0]
#                                                                  input_4[0][0]
# __________________________________________________________________________________________________
# Decoder (Model)                 (None, 96, 1)        1985        Encoder[1][0]
# ==================================================================================================
# Total params: 4,070
# Trainable params: 3,814
# Non-trainable params: 256
# __________________________________________________________________________________________________

# %%
save_folder = parentdir + dataset_dir + "weights/autoencoders/" + time.strftime("%Y%m%d_%H%M%S") + "/"
os.makedirs(save_folder)

autoencoder_kwargs.pop("loss", None)
model_kwargs = {"input_shape": input_shape, "latent_dim": latent_dim, "autoencoder_kwargs": autoencoder_kwargs}
dump(model_kwargs, save_folder + "model_kwargs.joblib")


reduce_lr = keras.callbacks.ReduceLROnPlateau(monitor='val_mean_squared_error', factor=0.5, patience=200, min_lr=0.0001)
file_path = save_folder + "vae" + "_best_weights.hdf5" 

model_checkpoint = keras.callbacks.ModelCheckpoint(filepath=file_path, 
                                                   monitor='val_mean_squared_error', 
                                                   save_weights_only = True, 
                                                   verbose = 1,
                                                   save_best_only=True)

callbacks = [reduce_lr, model_checkpoint]

# %%
#batch_size = 40
epochs=2000
autoencoder.fit(
    X_exp_train, 
    X_exp_train, 
    epochs=epochs, 
    validation_data=(X_exp_val, X_exp_val), 
    #batch_size=batch_size,
    callbacks = callbacks
)
IPython.display.Audio("beep.mp3", autoplay=True)
# Out:
# Train on 115 samples, validate on 29 samples
# Epoch 1/2000
# 115/115 [==============================] - 1s 6ms/step - loss: 8.1396 - mean_squared_error: 0.0293 - val_loss: 20.0840 - val_mean_squared_error: 0.1540
#
# Epoch 00001: val_mean_squared_error did not improve from 0.14331
# Epoch 2/2000
# 115/115 [==============================] - 1s 6ms/step - loss: 8.4466 - mean_squared_error: 0.0325 - val_loss: 19.7751 - val_mean_squared_error: 0.1508
#
# Epoch 00002: val_mean_squared_error did not improve from 0.14331
# Epoch 3/2000
# 115/115 [==============================] - 1s 6ms/step - loss: 8.2934 - mean_squared_error: 0.0309 - val_loss: 21.5330 - val_mean_squared_error: 0.1691
#
# Epoch 00003: val_mean_squared_error did not improve from 0.14331
# Epoch 4/2000
# 115/115 [==============================] - 1s 7ms/step - loss: 8.2482 - mean_squared_error: 0.0305 - val_loss: 20.6237 - val_mean_squared_error: 0.1597
#
# Epoch 00004: val_mean_squared_error did not improve from 0.14331
# Epoch 5/2000
# 115/115 [==============================] - 1s 9ms/step - loss: 8.4140 - mean_squared_error: 0.0323 - val_loss: 21.1763 - val_mean_squared_error: 0.1654
#
# Epoch 00005: val_mean_squared_error did not improve from 0.14331
# Epoch 6/2000
# 115/115 [==============================] - 1s 7ms/step - loss: 8.6011 - mean_squared_error: 0.0342 - val_loss: 21.7643 - val_mean_squared_error: 0.1715
#
# Epoch 00006: val_mean_squared_error did not improve from 0.14331
# Epoch 7/2000
# 115/115 [==============================] - 1s 6ms/step - loss: 7.9543 - mean_squared_error: 0.0275 - val_loss: 20.5685 - val_mean_squared_error: 0.1591
#
# Epoch 00007: val_mean_squared_error did not improve from 0.14331
# Epoch 8/2000
# 115/115 [==============================] - 1s 6ms/step - loss: 8.2658 - mean_squared_error: 0.0308 - val_loss: 20.0930 - val_mean_squared_error: 0.1543
#
# Epoch 00008: val_mean_squared_error did not improve from 0.14331
# Epoch 9/2000
# 115/115 [==============================] - 1s 6ms/step - loss: 8.4374 - mean_squared_error: 0.0327 - val_loss: 21.2643 - val_mean_squared_error: 0.1666
#
# Epoch 00009: val_mean_squared_error did not improve from 0.14331
# Epoch 10/2000
# 115/115 [==============================] - 1s 6ms/step - loss: 8.2053 - mean_squared_error: 0.0304 - val_loss: 20.2229 - val_mean_squared_error: 0.1559
#
# Epoch 00010: val_mean_squared_error did not improve from 0.14331
# Epoch 11/2000
# 115/115 [==============================] - 1s 6ms/step - loss: 7.9919 - mean_squared_error: 0.0282 - val_loss: 20.5029 - val_mean_squared_error: 0.1590
#
# Epoch 00011: val_mean_squared_error did not improve from 0.14331
# Epoch 12/2000
# 115/115 [==============================] - 1s 6ms/step - loss: 8.3518 - mean_squared_error: 0.0321 - val_loss: 20.1472 - val_mean_squared_error: 0.1553
#
# Epoch 00012: val_mean_squared_error did not improve from 0.14331
# Epoch 13/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.2835 - mean_squared_error: 0.0315 - val_loss: 21.2178 - val_mean_squared_error: 0.1665
#
# Epoch 00013: val_mean_squared_error did not improve from 0.14331
# Epoch 14/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.2524 - mean_squared_error: 0.0313 - val_loss: 19.8113 - val_mean_squared_error: 0.1518
#
# Epoch 00014: val_mean_squared_error did not improve from 0.14331
# Epoch 15/2000
# 115/115 [==============================] - 1s 6ms/step - loss: 8.0060 - mean_squared_error: 0.0287 - val_loss: 21.4324 - val_mean_squared_error: 0.1688
#
# Epoch 00015: val_mean_squared_error did not improve from 0.14331
# Epoch 16/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.2421 - mean_squared_error: 0.0312 - val_loss: 20.1758 - val_mean_squared_error: 0.1557
#
# Epoch 00016: val_mean_squared_error did not improve from 0.14331
# Epoch 17/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.4077 - mean_squared_error: 0.0329 - val_loss: 21.2071 - val_mean_squared_error: 0.1665
#
# Epoch 00017: val_mean_squared_error did not improve from 0.14331
# Epoch 18/2000
# 115/115 [==============================] - 1s 8ms/step - loss: 8.0313 - mean_squared_error: 0.0290 - val_loss: 20.7059 - val_mean_squared_error: 0.1614
#
# Epoch 00018: val_mean_squared_error did not improve from 0.14331
# Epoch 19/2000
# 115/115 [==============================] - 1s 6ms/step - loss: 8.2724 - mean_squared_error: 0.0315 - val_loss: 20.5119 - val_mean_squared_error: 0.1595
#
# Epoch 00019: val_mean_squared_error did not improve from 0.14331
# Epoch 20/2000
# 115/115 [==============================] - 1s 6ms/step - loss: 8.2197 - mean_squared_error: 0.0309 - val_loss: 19.6668 - val_mean_squared_error: 0.1508
#
# Epoch 00020: val_mean_squared_error did not improve from 0.14331
# Epoch 21/2000
# 115/115 [==============================] - 1s 6ms/step - loss: 8.3418 - mean_squared_error: 0.0323 - val_loss: 19.9295 - val_mean_squared_error: 0.1535
#
# Epoch 00021: val_mean_squared_error did not improve from 0.14331
# Epoch 22/2000
# 115/115 [==============================] - 1s 6ms/step - loss: 8.4102 - mean_squared_error: 0.0330 - val_loss: 21.6438 - val_mean_squared_error: 0.1714
#
# Epoch 00022: val_mean_squared_error did not improve from 0.14331
# Epoch 23/2000
# 115/115 [==============================] - 1s 6ms/step - loss: 8.4346 - mean_squared_error: 0.0332 - val_loss: 20.4759 - val_mean_squared_error: 0.1592
#
# Epoch 00023: val_mean_squared_error did not improve from 0.14331
# Epoch 24/2000
# 115/115 [==============================] - 1s 6ms/step - loss: 8.7327 - mean_squared_error: 0.0362 - val_loss: 22.2537 - val_mean_squared_error: 0.1776
#
# Epoch 00024: val_mean_squared_error did not improve from 0.14331
# Epoch 25/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.1729 - mean_squared_error: 0.0303 - val_loss: 20.6314 - val_mean_squared_error: 0.1606
#
# Epoch 00025: val_mean_squared_error did not improve from 0.14331
# Epoch 26/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 7.9749 - mean_squared_error: 0.0281 - val_loss: 21.3290 - val_mean_squared_error: 0.1678
#
# Epoch 00026: val_mean_squared_error did not improve from 0.14331
# Epoch 27/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.2482 - mean_squared_error: 0.0310 - val_loss: 20.6291 - val_mean_squared_error: 0.1605
#
# Epoch 00027: val_mean_squared_error did not improve from 0.14331
# Epoch 28/2000
# 115/115 [==============================] - 1s 6ms/step - loss: 8.2408 - mean_squared_error: 0.0310 - val_loss: 19.9910 - val_mean_squared_error: 0.1539
#
# Epoch 00028: val_mean_squared_error did not improve from 0.14331
# Epoch 29/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.2115 - mean_squared_error: 0.0308 - val_loss: 20.4388 - val_mean_squared_error: 0.1586
#
# Epoch 00029: val_mean_squared_error did not improve from 0.14331
# Epoch 30/2000
# 115/115 [==============================] - 1s 6ms/step - loss: 8.1512 - mean_squared_error: 0.0302 - val_loss: 19.5894 - val_mean_squared_error: 0.1498
#
# Epoch 00030: val_mean_squared_error did not improve from 0.14331
# Epoch 31/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.2764 - mean_squared_error: 0.0315 - val_loss: 21.6789 - val_mean_squared_error: 0.1717
#
# Epoch 00031: val_mean_squared_error did not improve from 0.14331
# Epoch 32/2000
# 115/115 [==============================] - 1s 6ms/step - loss: 8.4508 - mean_squared_error: 0.0333 - val_loss: 20.4802 - val_mean_squared_error: 0.1591
#
# Epoch 00032: val_mean_squared_error did not improve from 0.14331
# Epoch 33/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.2853 - mean_squared_error: 0.0314 - val_loss: 21.1352 - val_mean_squared_error: 0.1659
#
# Epoch 00033: val_mean_squared_error did not improve from 0.14331
# Epoch 34/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.2021 - mean_squared_error: 0.0305 - val_loss: 20.5566 - val_mean_squared_error: 0.1597
#
# Epoch 00034: val_mean_squared_error did not improve from 0.14331
# Epoch 35/2000
# 115/115 [==============================] - 1s 6ms/step - loss: 8.7659 - mean_squared_error: 0.0363 - val_loss: 20.3191 - val_mean_squared_error: 0.1572
#
# Epoch 00035: val_mean_squared_error did not improve from 0.14331
# Epoch 36/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.2189 - mean_squared_error: 0.0304 - val_loss: 20.8054 - val_mean_squared_error: 0.1621
#
# Epoch 00036: val_mean_squared_error did not improve from 0.14331
# Epoch 37/2000
# 115/115 [==============================] - 1s 6ms/step - loss: 8.3991 - mean_squared_error: 0.0322 - val_loss: 20.6990 - val_mean_squared_error: 0.1610
#
# Epoch 00037: val_mean_squared_error did not improve from 0.14331
# Epoch 38/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.3895 - mean_squared_error: 0.0321 - val_loss: 20.0967 - val_mean_squared_error: 0.1547
#
# Epoch 00038: val_mean_squared_error did not improve from 0.14331
# Epoch 39/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.5294 - mean_squared_error: 0.0335 - val_loss: 20.6009 - val_mean_squared_error: 0.1599
#
# Epoch 00039: val_mean_squared_error did not improve from 0.14331
# Epoch 40/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.0427 - mean_squared_error: 0.0284 - val_loss: 21.7696 - val_mean_squared_error: 0.1720
#
# Epoch 00040: val_mean_squared_error did not improve from 0.14331
# Epoch 41/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.3953 - mean_squared_error: 0.0322 - val_loss: 21.0724 - val_mean_squared_error: 0.1648
#
# Epoch 00041: val_mean_squared_error did not improve from 0.14331
# Epoch 42/2000
# 115/115 [==============================] - 1s 6ms/step - loss: 8.5117 - mean_squared_error: 0.0334 - val_loss: 19.7672 - val_mean_squared_error: 0.1511
#
# Epoch 00042: val_mean_squared_error did not improve from 0.14331
# Epoch 43/2000
# 115/115 [==============================] - 1s 6ms/step - loss: 8.1862 - mean_squared_error: 0.0299 - val_loss: 21.1316 - val_mean_squared_error: 0.1652
#
# Epoch 00043: val_mean_squared_error did not improve from 0.14331
# Epoch 44/2000
# 115/115 [==============================] - 1s 6ms/step - loss: 8.5275 - mean_squared_error: 0.0334 - val_loss: 21.1454 - val_mean_squared_error: 0.1652
#
# Epoch 00044: val_mean_squared_error did not improve from 0.14331
# Epoch 45/2000
# 115/115 [==============================] - 1s 7ms/step - loss: 8.1525 - mean_squared_error: 0.0293 - val_loss: 19.7516 - val_mean_squared_error: 0.1506
#
# Epoch 00045: val_mean_squared_error did not improve from 0.14331
# Epoch 46/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.0964 - mean_squared_error: 0.0287 - val_loss: 20.0964 - val_mean_squared_error: 0.1543
#
# Epoch 00046: val_mean_squared_error did not improve from 0.14331
# Epoch 47/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.2195 - mean_squared_error: 0.0301 - val_loss: 20.5250 - val_mean_squared_error: 0.1587
#
# Epoch 00047: val_mean_squared_error did not improve from 0.14331
# Epoch 48/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.3281 - mean_squared_error: 0.0313 - val_loss: 20.6882 - val_mean_squared_error: 0.1605
#
# Epoch 00048: val_mean_squared_error did not improve from 0.14331
# Epoch 49/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.3628 - mean_squared_error: 0.0318 - val_loss: 21.6174 - val_mean_squared_error: 0.1701
#
# Epoch 00049: val_mean_squared_error did not improve from 0.14331
# Epoch 50/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.6665 - mean_squared_error: 0.0350 - val_loss: 21.0538 - val_mean_squared_error: 0.1642
#
# Epoch 00050: val_mean_squared_error did not improve from 0.14331
# Epoch 51/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 7.9506 - mean_squared_error: 0.0276 - val_loss: 20.7767 - val_mean_squared_error: 0.1614
#
# Epoch 00051: val_mean_squared_error did not improve from 0.14331
# Epoch 52/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.4202 - mean_squared_error: 0.0325 - val_loss: 21.8494 - val_mean_squared_error: 0.1727
#
# Epoch 00052: val_mean_squared_error did not improve from 0.14331
# Epoch 53/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.3037 - mean_squared_error: 0.0313 - val_loss: 20.3496 - val_mean_squared_error: 0.1571
#
# Epoch 00053: val_mean_squared_error did not improve from 0.14331
# Epoch 54/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.3244 - mean_squared_error: 0.0315 - val_loss: 21.1200 - val_mean_squared_error: 0.1651
#
# Epoch 00054: val_mean_squared_error did not improve from 0.14331
# Epoch 55/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.3050 - mean_squared_error: 0.0313 - val_loss: 21.3995 - val_mean_squared_error: 0.1681
#
# Epoch 00055: val_mean_squared_error did not improve from 0.14331
# Epoch 56/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.2794 - mean_squared_error: 0.0311 - val_loss: 21.4643 - val_mean_squared_error: 0.1688
#
# Epoch 00056: val_mean_squared_error did not improve from 0.14331
# Epoch 57/2000
# 115/115 [==============================] - 1s 4ms/step - loss: 8.1856 - mean_squared_error: 0.0301 - val_loss: 20.6523 - val_mean_squared_error: 0.1604
#
# Epoch 00057: val_mean_squared_error did not improve from 0.14331
# Epoch 58/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.2609 - mean_squared_error: 0.0308 - val_loss: 20.0015 - val_mean_squared_error: 0.1536
#
# Epoch 00058: val_mean_squared_error did not improve from 0.14331
# Epoch 59/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.2471 - mean_squared_error: 0.0307 - val_loss: 21.3997 - val_mean_squared_error: 0.1680
#
# Epoch 00059: val_mean_squared_error did not improve from 0.14331
# Epoch 60/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.3053 - mean_squared_error: 0.0313 - val_loss: 20.8216 - val_mean_squared_error: 0.1620
#
# Epoch 00060: val_mean_squared_error did not improve from 0.14331
# Epoch 61/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.0757 - mean_squared_error: 0.0288 - val_loss: 20.9228 - val_mean_squared_error: 0.1630
#
# Epoch 00061: val_mean_squared_error did not improve from 0.14331
# Epoch 62/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.5791 - mean_squared_error: 0.0341 - val_loss: 20.8027 - val_mean_squared_error: 0.1618
#
# Epoch 00062: val_mean_squared_error did not improve from 0.14331
# Epoch 63/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.3775 - mean_squared_error: 0.0321 - val_loss: 20.1744 - val_mean_squared_error: 0.1552
#
# Epoch 00063: val_mean_squared_error did not improve from 0.14331
# Epoch 64/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.3286 - mean_squared_error: 0.0315 - val_loss: 20.3408 - val_mean_squared_error: 0.1568
#
# Epoch 00064: val_mean_squared_error did not improve from 0.14331
# Epoch 65/2000
# 115/115 [==============================] - 1s 6ms/step - loss: 8.0981 - mean_squared_error: 0.0290 - val_loss: 20.1730 - val_mean_squared_error: 0.1551
#
# Epoch 00065: val_mean_squared_error did not improve from 0.14331
# Epoch 66/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.2778 - mean_squared_error: 0.0309 - val_loss: 20.2571 - val_mean_squared_error: 0.1561
#
# Epoch 00066: val_mean_squared_error did not improve from 0.14331
# Epoch 67/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.0074 - mean_squared_error: 0.0281 - val_loss: 20.8512 - val_mean_squared_error: 0.1624
#
# Epoch 00067: val_mean_squared_error did not improve from 0.14331
# Epoch 68/2000
# 115/115 [==============================] - 1s 6ms/step - loss: 8.3347 - mean_squared_error: 0.0317 - val_loss: 21.2559 - val_mean_squared_error: 0.1667
#
# Epoch 00068: val_mean_squared_error did not improve from 0.14331
# Epoch 69/2000
# 115/115 [==============================] - 1s 7ms/step - loss: 8.1635 - mean_squared_error: 0.0300 - val_loss: 19.7963 - val_mean_squared_error: 0.1514
#
# Epoch 00069: val_mean_squared_error did not improve from 0.14331
# Epoch 70/2000
# 115/115 [==============================] - 1s 6ms/step - loss: 8.3212 - mean_squared_error: 0.0317 - val_loss: 20.1908 - val_mean_squared_error: 0.1555
#
# Epoch 00070: val_mean_squared_error did not improve from 0.14331
# Epoch 71/2000
# 115/115 [==============================] - 1s 6ms/step - loss: 8.1012 - mean_squared_error: 0.0295 - val_loss: 21.1201 - val_mean_squared_error: 0.1653
#
# Epoch 00071: val_mean_squared_error did not improve from 0.14331
# Epoch 72/2000
# 115/115 [==============================] - 1s 7ms/step - loss: 8.1508 - mean_squared_error: 0.0301 - val_loss: 20.4530 - val_mean_squared_error: 0.1585
#
# Epoch 00072: val_mean_squared_error did not improve from 0.14331
# Epoch 73/2000
# 115/115 [==============================] - 1s 6ms/step - loss: 8.3118 - mean_squared_error: 0.0317 - val_loss: 21.0574 - val_mean_squared_error: 0.1647
#
# Epoch 00073: val_mean_squared_error did not improve from 0.14331
# Epoch 74/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.0603 - mean_squared_error: 0.0290 - val_loss: 19.8434 - val_mean_squared_error: 0.1519
#
# Epoch 00074: val_mean_squared_error did not improve from 0.14331
# Epoch 75/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.3590 - mean_squared_error: 0.0321 - val_loss: 21.6431 - val_mean_squared_error: 0.1706
#
# Epoch 00075: val_mean_squared_error did not improve from 0.14331
# Epoch 76/2000
# 115/115 [==============================] - 1s 7ms/step - loss: 8.4613 - mean_squared_error: 0.0331 - val_loss: 20.8806 - val_mean_squared_error: 0.1626
#
# Epoch 00076: val_mean_squared_error did not improve from 0.14331
# Epoch 77/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 7.9799 - mean_squared_error: 0.0281 - val_loss: 22.0030 - val_mean_squared_error: 0.1743
#
# Epoch 00077: val_mean_squared_error did not improve from 0.14331
# Epoch 78/2000
# 115/115 [==============================] - 1s 6ms/step - loss: 8.5700 - mean_squared_error: 0.0343 - val_loss: 20.3355 - val_mean_squared_error: 0.1570
#
# Epoch 00078: val_mean_squared_error did not improve from 0.14331
# Epoch 79/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.1830 - mean_squared_error: 0.0302 - val_loss: 21.0608 - val_mean_squared_error: 0.1646
#
# Epoch 00079: val_mean_squared_error did not improve from 0.14331
# Epoch 80/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.8949 - mean_squared_error: 0.0376 - val_loss: 20.2809 - val_mean_squared_error: 0.1565
#
# Epoch 00080: val_mean_squared_error did not improve from 0.14331
# Epoch 81/2000
# 115/115 [==============================] - 1s 7ms/step - loss: 8.2502 - mean_squared_error: 0.0308 - val_loss: 21.0654 - val_mean_squared_error: 0.1647
#
# Epoch 00081: val_mean_squared_error did not improve from 0.14331
# Epoch 82/2000
# 115/115 [==============================] - 1s 7ms/step - loss: 8.1530 - mean_squared_error: 0.0297 - val_loss: 21.0489 - val_mean_squared_error: 0.1646
#
# Epoch 00082: val_mean_squared_error did not improve from 0.14331
# Epoch 83/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.4388 - mean_squared_error: 0.0327 - val_loss: 20.0559 - val_mean_squared_error: 0.1543
#
# Epoch 00083: val_mean_squared_error did not improve from 0.14331
# Epoch 84/2000
# 115/115 [==============================] - 1s 4ms/step - loss: 8.1658 - mean_squared_error: 0.0298 - val_loss: 19.6567 - val_mean_squared_error: 0.1501
#
# Epoch 00084: val_mean_squared_error did not improve from 0.14331
# Epoch 85/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.0415 - mean_squared_error: 0.0285 - val_loss: 20.6223 - val_mean_squared_error: 0.1602
#
# Epoch 00085: val_mean_squared_error did not improve from 0.14331
# Epoch 86/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.3290 - mean_squared_error: 0.0316 - val_loss: 21.8467 - val_mean_squared_error: 0.1730
#
# Epoch 00086: val_mean_squared_error did not improve from 0.14331
# Epoch 87/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.5472 - mean_squared_error: 0.0338 - val_loss: 19.9463 - val_mean_squared_error: 0.1530
#
# Epoch 00087: val_mean_squared_error did not improve from 0.14331
# Epoch 88/2000
# 115/115 [==============================] - 1s 7ms/step - loss: 8.0155 - mean_squared_error: 0.0281 - val_loss: 20.9350 - val_mean_squared_error: 0.1633
#
# Epoch 00088: val_mean_squared_error did not improve from 0.14331
# Epoch 89/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.7794 - mean_squared_error: 0.0361 - val_loss: 19.1691 - val_mean_squared_error: 0.1450
#
# Epoch 00089: val_mean_squared_error did not improve from 0.14331
# Epoch 90/2000
# 115/115 [==============================] - 1s 6ms/step - loss: 8.3660 - mean_squared_error: 0.0317 - val_loss: 20.0062 - val_mean_squared_error: 0.1536
#
# Epoch 00090: val_mean_squared_error did not improve from 0.14331
# Epoch 91/2000
# 115/115 [==============================] - 1s 7ms/step - loss: 8.5362 - mean_squared_error: 0.0334 - val_loss: 20.6505 - val_mean_squared_error: 0.1602
#
# Epoch 00091: val_mean_squared_error did not improve from 0.14331
# Epoch 92/2000
# 115/115 [==============================] - 1s 6ms/step - loss: 8.4637 - mean_squared_error: 0.0327 - val_loss: 20.5822 - val_mean_squared_error: 0.1594
#
# Epoch 00092: val_mean_squared_error did not improve from 0.14331
# Epoch 93/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.2673 - mean_squared_error: 0.0308 - val_loss: 21.0783 - val_mean_squared_error: 0.1645
#
# Epoch 00093: val_mean_squared_error did not improve from 0.14331
# Epoch 94/2000
# 115/115 [==============================] - 1s 6ms/step - loss: 8.2170 - mean_squared_error: 0.0303 - val_loss: 21.9904 - val_mean_squared_error: 0.1741
#
# Epoch 00094: val_mean_squared_error did not improve from 0.14331
# Epoch 95/2000
# 115/115 [==============================] - 1s 7ms/step - loss: 8.2277 - mean_squared_error: 0.0305 - val_loss: 20.7972 - val_mean_squared_error: 0.1616
#
# Epoch 00095: val_mean_squared_error did not improve from 0.14331
# Epoch 96/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.3125 - mean_squared_error: 0.0314 - val_loss: 19.9284 - val_mean_squared_error: 0.1526
#
# Epoch 00096: val_mean_squared_error did not improve from 0.14331
# Epoch 97/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.0778 - mean_squared_error: 0.0291 - val_loss: 21.5563 - val_mean_squared_error: 0.1697
#
# Epoch 00097: val_mean_squared_error did not improve from 0.14331
# Epoch 98/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.2339 - mean_squared_error: 0.0308 - val_loss: 20.4236 - val_mean_squared_error: 0.1579
#
# Epoch 00098: val_mean_squared_error did not improve from 0.14331
# Epoch 99/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.1886 - mean_squared_error: 0.0303 - val_loss: 20.3488 - val_mean_squared_error: 0.1572
#
# Epoch 00099: val_mean_squared_error did not improve from 0.14331
# Epoch 100/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.1633 - mean_squared_error: 0.0301 - val_loss: 20.9230 - val_mean_squared_error: 0.1632
#
# Epoch 00100: val_mean_squared_error did not improve from 0.14331
# Epoch 101/2000
# 115/115 [==============================] - 1s 6ms/step - loss: 8.0103 - mean_squared_error: 0.0285 - val_loss: 21.3502 - val_mean_squared_error: 0.1677
#
# Epoch 00101: val_mean_squared_error did not improve from 0.14331
# Epoch 102/2000
# 115/115 [==============================] - 1s 6ms/step - loss: 8.1962 - mean_squared_error: 0.0305 - val_loss: 19.8100 - val_mean_squared_error: 0.1516
#
# Epoch 00102: val_mean_squared_error did not improve from 0.14331
# Epoch 103/2000
# 115/115 [==============================] - 1s 6ms/step - loss: 8.1760 - mean_squared_error: 0.0302 - val_loss: 20.4509 - val_mean_squared_error: 0.1582
#
# Epoch 00103: val_mean_squared_error did not improve from 0.14331
# Epoch 104/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.0793 - mean_squared_error: 0.0291 - val_loss: 21.4735 - val_mean_squared_error: 0.1689
#
# Epoch 00104: val_mean_squared_error did not improve from 0.14331
# Epoch 105/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.3334 - mean_squared_error: 0.0318 - val_loss: 20.0937 - val_mean_squared_error: 0.1544
#
# Epoch 00105: val_mean_squared_error did not improve from 0.14331
# Epoch 106/2000
# 115/115 [==============================] - 1s 7ms/step - loss: 8.2840 - mean_squared_error: 0.0312 - val_loss: 19.6670 - val_mean_squared_error: 0.1499
#
# Epoch 00106: val_mean_squared_error did not improve from 0.14331
# Epoch 107/2000
# 115/115 [==============================] - 1s 6ms/step - loss: 8.7554 - mean_squared_error: 0.0362 - val_loss: 20.2116 - val_mean_squared_error: 0.1557
#
# Epoch 00107: val_mean_squared_error did not improve from 0.14331
# Epoch 108/2000
# 115/115 [==============================] - 1s 6ms/step - loss: 8.3992 - mean_squared_error: 0.0324 - val_loss: 21.1888 - val_mean_squared_error: 0.1659
#
# Epoch 00108: val_mean_squared_error did not improve from 0.14331
# Epoch 109/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.4427 - mean_squared_error: 0.0328 - val_loss: 20.0743 - val_mean_squared_error: 0.1542
#
# Epoch 00109: val_mean_squared_error did not improve from 0.14331
# Epoch 110/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.3277 - mean_squared_error: 0.0315 - val_loss: 21.0382 - val_mean_squared_error: 0.1640
#
# Epoch 00110: val_mean_squared_error did not improve from 0.14331
# Epoch 111/2000
# 115/115 [==============================] - 1s 4ms/step - loss: 8.5546 - mean_squared_error: 0.0337 - val_loss: 20.1464 - val_mean_squared_error: 0.1547
#
# Epoch 00111: val_mean_squared_error did not improve from 0.14331
# Epoch 112/2000
# 115/115 [==============================] - 1s 4ms/step - loss: 8.4570 - mean_squared_error: 0.0327 - val_loss: 20.0222 - val_mean_squared_error: 0.1535
#
# Epoch 00112: val_mean_squared_error did not improve from 0.14331
# Epoch 113/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.0477 - mean_squared_error: 0.0284 - val_loss: 19.9832 - val_mean_squared_error: 0.1531
#
# Epoch 00113: val_mean_squared_error did not improve from 0.14331
# Epoch 114/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.3226 - mean_squared_error: 0.0312 - val_loss: 20.0819 - val_mean_squared_error: 0.1541
#
# Epoch 00114: val_mean_squared_error did not improve from 0.14331
# Epoch 115/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.0956 - mean_squared_error: 0.0289 - val_loss: 20.1644 - val_mean_squared_error: 0.1551
#
# Epoch 00115: val_mean_squared_error did not improve from 0.14331
# Epoch 116/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.1876 - mean_squared_error: 0.0298 - val_loss: 20.7374 - val_mean_squared_error: 0.1611
#
# Epoch 00116: val_mean_squared_error did not improve from 0.14331
# Epoch 117/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.5311 - mean_squared_error: 0.0334 - val_loss: 20.5558 - val_mean_squared_error: 0.1591
#
# Epoch 00117: val_mean_squared_error did not improve from 0.14331
# Epoch 118/2000
# 115/115 [==============================] - 1s 4ms/step - loss: 8.3706 - mean_squared_error: 0.0317 - val_loss: 20.6704 - val_mean_squared_error: 0.1602
#
# Epoch 00118: val_mean_squared_error did not improve from 0.14331
# Epoch 119/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.3391 - mean_squared_error: 0.0313 - val_loss: 20.6151 - val_mean_squared_error: 0.1595
#
# Epoch 00119: val_mean_squared_error did not improve from 0.14331
# Epoch 120/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.7041 - mean_squared_error: 0.0350 - val_loss: 19.7418 - val_mean_squared_error: 0.1502
#
# Epoch 00120: val_mean_squared_error did not improve from 0.14331
# Epoch 121/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.3148 - mean_squared_error: 0.0308 - val_loss: 20.9956 - val_mean_squared_error: 0.1632
#
# Epoch 00121: val_mean_squared_error did not improve from 0.14331
# Epoch 122/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.3320 - mean_squared_error: 0.0309 - val_loss: 20.2812 - val_mean_squared_error: 0.1558
#
# Epoch 00122: val_mean_squared_error did not improve from 0.14331
# Epoch 123/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.3924 - mean_squared_error: 0.0315 - val_loss: 21.7614 - val_mean_squared_error: 0.1712
#
# Epoch 00123: val_mean_squared_error did not improve from 0.14331
# Epoch 124/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.1458 - mean_squared_error: 0.0289 - val_loss: 20.6606 - val_mean_squared_error: 0.1597
#
# Epoch 00124: val_mean_squared_error did not improve from 0.14331
# Epoch 125/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.3615 - mean_squared_error: 0.0311 - val_loss: 20.6051 - val_mean_squared_error: 0.1592
#
# Epoch 00125: val_mean_squared_error did not improve from 0.14331
# Epoch 126/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.1549 - mean_squared_error: 0.0289 - val_loss: 20.1480 - val_mean_squared_error: 0.1545
#
# Epoch 00126: val_mean_squared_error did not improve from 0.14331
# Epoch 127/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.3474 - mean_squared_error: 0.0310 - val_loss: 19.8061 - val_mean_squared_error: 0.1510
#
# Epoch 00127: val_mean_squared_error did not improve from 0.14331
# Epoch 128/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.0409 - mean_squared_error: 0.0279 - val_loss: 21.0731 - val_mean_squared_error: 0.1644
#
# Epoch 00128: val_mean_squared_error did not improve from 0.14331
# Epoch 129/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.4135 - mean_squared_error: 0.0320 - val_loss: 20.5690 - val_mean_squared_error: 0.1592
#
# Epoch 00129: val_mean_squared_error did not improve from 0.14331
# Epoch 130/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.3848 - mean_squared_error: 0.0318 - val_loss: 20.8663 - val_mean_squared_error: 0.1623
#
# Epoch 00130: val_mean_squared_error did not improve from 0.14331
# Epoch 131/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.2085 - mean_squared_error: 0.0300 - val_loss: 20.8711 - val_mean_squared_error: 0.1624
#
# Epoch 00131: val_mean_squared_error did not improve from 0.14331
# Epoch 132/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.1673 - mean_squared_error: 0.0296 - val_loss: 20.4285 - val_mean_squared_error: 0.1578
#
# Epoch 00132: val_mean_squared_error did not improve from 0.14331
# Epoch 133/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.0468 - mean_squared_error: 0.0284 - val_loss: 20.9293 - val_mean_squared_error: 0.1631
#
# Epoch 00133: val_mean_squared_error did not improve from 0.14331
# Epoch 134/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.2018 - mean_squared_error: 0.0302 - val_loss: 20.6471 - val_mean_squared_error: 0.1602
#
# Epoch 00134: val_mean_squared_error did not improve from 0.14331
# Epoch 135/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.2141 - mean_squared_error: 0.0304 - val_loss: 20.2490 - val_mean_squared_error: 0.1561
#
# Epoch 00135: val_mean_squared_error did not improve from 0.14331
# Epoch 136/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.3707 - mean_squared_error: 0.0320 - val_loss: 20.8890 - val_mean_squared_error: 0.1627
#
# Epoch 00136: val_mean_squared_error did not improve from 0.14331
# Epoch 137/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.4420 - mean_squared_error: 0.0327 - val_loss: 21.0410 - val_mean_squared_error: 0.1642
#
# Epoch 00137: val_mean_squared_error did not improve from 0.14331
# Epoch 138/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.4766 - mean_squared_error: 0.0329 - val_loss: 20.6336 - val_mean_squared_error: 0.1599
#
# Epoch 00138: val_mean_squared_error did not improve from 0.14331
# Epoch 139/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.1988 - mean_squared_error: 0.0299 - val_loss: 20.2098 - val_mean_squared_error: 0.1554
#
# Epoch 00139: val_mean_squared_error did not improve from 0.14331
# Epoch 140/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.2043 - mean_squared_error: 0.0299 - val_loss: 20.7392 - val_mean_squared_error: 0.1609
#
# Epoch 00140: val_mean_squared_error did not improve from 0.14331
# Epoch 141/2000
# 115/115 [==============================] - 1s 4ms/step - loss: 8.5779 - mean_squared_error: 0.0338 - val_loss: 20.5293 - val_mean_squared_error: 0.1587
#
# Epoch 00141: val_mean_squared_error did not improve from 0.14331
# Epoch 142/2000
# 115/115 [==============================] - 0s 4ms/step - loss: 8.1576 - mean_squared_error: 0.0294 - val_loss: 21.2747 - val_mean_squared_error: 0.1664
#
# Epoch 00142: val_mean_squared_error did not improve from 0.14331
# Epoch 143/2000
# 115/115 [==============================] - 1s 4ms/step - loss: 8.2030 - mean_squared_error: 0.0299 - val_loss: 20.3004 - val_mean_squared_error: 0.1563
#
# Epoch 00143: val_mean_squared_error did not improve from 0.14331
# Epoch 144/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.7118 - mean_squared_error: 0.0352 - val_loss: 21.0399 - val_mean_squared_error: 0.1641
#
# Epoch 00144: val_mean_squared_error did not improve from 0.14331
# Epoch 145/2000
# 115/115 [==============================] - 1s 4ms/step - loss: 8.5464 - mean_squared_error: 0.0336 - val_loss: 21.0859 - val_mean_squared_error: 0.1646
#
# Epoch 00145: val_mean_squared_error did not improve from 0.14331
# Epoch 146/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.1266 - mean_squared_error: 0.0292 - val_loss: 21.7169 - val_mean_squared_error: 0.1711
#
# Epoch 00146: val_mean_squared_error did not improve from 0.14331
# Epoch 147/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.2942 - mean_squared_error: 0.0309 - val_loss: 20.0323 - val_mean_squared_error: 0.1535
#
# Epoch 00147: val_mean_squared_error did not improve from 0.14331
# Epoch 148/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.2190 - mean_squared_error: 0.0301 - val_loss: 21.3161 - val_mean_squared_error: 0.1667
#
# Epoch 00148: val_mean_squared_error did not improve from 0.14331
# Epoch 149/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.0988 - mean_squared_error: 0.0288 - val_loss: 21.3029 - val_mean_squared_error: 0.1665
#
# Epoch 00149: val_mean_squared_error did not improve from 0.14331
# Epoch 150/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 7.9589 - mean_squared_error: 0.0273 - val_loss: 22.7227 - val_mean_squared_error: 0.1813
#
# Epoch 00150: val_mean_squared_error did not improve from 0.14331
# Epoch 151/2000
# 115/115 [==============================] - 1s 4ms/step - loss: 8.1743 - mean_squared_error: 0.0296 - val_loss: 20.4621 - val_mean_squared_error: 0.1578
#
# Epoch 00151: val_mean_squared_error did not improve from 0.14331
# Epoch 152/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.2777 - mean_squared_error: 0.0307 - val_loss: 20.3330 - val_mean_squared_error: 0.1565
#
# Epoch 00152: val_mean_squared_error did not improve from 0.14331
# Epoch 153/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.0090 - mean_squared_error: 0.0280 - val_loss: 20.2860 - val_mean_squared_error: 0.1560
#
# Epoch 00153: val_mean_squared_error did not improve from 0.14331
# Epoch 154/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.2743 - mean_squared_error: 0.0308 - val_loss: 20.8675 - val_mean_squared_error: 0.1622
#
# Epoch 00154: val_mean_squared_error did not improve from 0.14331
# Epoch 155/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.1897 - mean_squared_error: 0.0301 - val_loss: 20.1154 - val_mean_squared_error: 0.1544
#
# Epoch 00155: val_mean_squared_error did not improve from 0.14331
# Epoch 156/2000
# 115/115 [==============================] - 1s 6ms/step - loss: 8.0699 - mean_squared_error: 0.0289 - val_loss: 20.7128 - val_mean_squared_error: 0.1607
#
# Epoch 00156: val_mean_squared_error did not improve from 0.14331
# Epoch 157/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.5896 - mean_squared_error: 0.0345 - val_loss: 20.0270 - val_mean_squared_error: 0.1536
#
# Epoch 00157: val_mean_squared_error did not improve from 0.14331
# Epoch 158/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.4378 - mean_squared_error: 0.0329 - val_loss: 22.2257 - val_mean_squared_error: 0.1765
#
# Epoch 00158: val_mean_squared_error did not improve from 0.14331
# Epoch 159/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.1419 - mean_squared_error: 0.0298 - val_loss: 19.7195 - val_mean_squared_error: 0.1503
#
# Epoch 00159: val_mean_squared_error did not improve from 0.14331
# Epoch 160/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.7768 - mean_squared_error: 0.0364 - val_loss: 20.8849 - val_mean_squared_error: 0.1624
#
# Epoch 00160: val_mean_squared_error did not improve from 0.14331
# Epoch 161/2000
# 115/115 [==============================] - 1s 6ms/step - loss: 8.3069 - mean_squared_error: 0.0312 - val_loss: 20.8341 - val_mean_squared_error: 0.1618
#
# Epoch 00161: val_mean_squared_error did not improve from 0.14331
# Epoch 162/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.3221 - mean_squared_error: 0.0313 - val_loss: 21.5757 - val_mean_squared_error: 0.1695
#
# Epoch 00162: val_mean_squared_error did not improve from 0.14331
# Epoch 163/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.1930 - mean_squared_error: 0.0298 - val_loss: 19.1716 - val_mean_squared_error: 0.1444
#
# Epoch 00163: val_mean_squared_error did not improve from 0.14331
# Epoch 164/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.4318 - mean_squared_error: 0.0323 - val_loss: 21.1531 - val_mean_squared_error: 0.1651
#
# Epoch 00164: val_mean_squared_error did not improve from 0.14331
# Epoch 165/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 7.9884 - mean_squared_error: 0.0277 - val_loss: 19.8955 - val_mean_squared_error: 0.1520
#
# Epoch 00165: val_mean_squared_error did not improve from 0.14331
# Epoch 166/2000
# 115/115 [==============================] - 1s 9ms/step - loss: 8.3504 - mean_squared_error: 0.0315 - val_loss: 20.9233 - val_mean_squared_error: 0.1627
#
# Epoch 00166: val_mean_squared_error did not improve from 0.14331
# Epoch 167/2000
# 115/115 [==============================] - 1s 10ms/step - loss: 8.1573 - mean_squared_error: 0.0295 - val_loss: 20.3474 - val_mean_squared_error: 0.1567
#
# Epoch 00167: val_mean_squared_error did not improve from 0.14331
# Epoch 168/2000
# 115/115 [==============================] - 1s 11ms/step - loss: 8.1520 - mean_squared_error: 0.0295 - val_loss: 20.4952 - val_mean_squared_error: 0.1583
#
# Epoch 00168: val_mean_squared_error did not improve from 0.14331
# Epoch 169/2000
# 115/115 [==============================] - 1s 12ms/step - loss: 8.6063 - mean_squared_error: 0.0343 - val_loss: 21.6709 - val_mean_squared_error: 0.1705
#
# Epoch 00169: val_mean_squared_error did not improve from 0.14331
# Epoch 170/2000
# 115/115 [==============================] - 1s 12ms/step - loss: 8.4455 - mean_squared_error: 0.0326 - val_loss: 20.8421 - val_mean_squared_error: 0.1619
#
# Epoch 00170: val_mean_squared_error did not improve from 0.14331
# Epoch 171/2000
# 115/115 [==============================] - 1s 11ms/step - loss: 8.6685 - mean_squared_error: 0.0349 - val_loss: 20.7960 - val_mean_squared_error: 0.1616
#
# Epoch 00171: val_mean_squared_error did not improve from 0.14331
# Epoch 172/2000
# 115/115 [==============================] - 1s 10ms/step - loss: 8.0637 - mean_squared_error: 0.0286 - val_loss: 20.2105 - val_mean_squared_error: 0.1556
#
# Epoch 00172: val_mean_squared_error did not improve from 0.14331
# Epoch 173/2000
# 115/115 [==============================] - 1s 10ms/step - loss: 8.5117 - mean_squared_error: 0.0334 - val_loss: 20.7220 - val_mean_squared_error: 0.1610
#
# Epoch 00173: val_mean_squared_error did not improve from 0.14331
# Epoch 174/2000
# 115/115 [==============================] - 1s 9ms/step - loss: 8.1324 - mean_squared_error: 0.0295 - val_loss: 20.5555 - val_mean_squared_error: 0.1592
#
# Epoch 00174: val_mean_squared_error did not improve from 0.14331
# Epoch 175/2000
# 115/115 [==============================] - 1s 10ms/step - loss: 8.2310 - mean_squared_error: 0.0305 - val_loss: 19.9926 - val_mean_squared_error: 0.1533
#
# Epoch 00175: val_mean_squared_error did not improve from 0.14331
# Epoch 176/2000
# 115/115 [==============================] - 1s 10ms/step - loss: 8.2849 - mean_squared_error: 0.0310 - val_loss: 20.8018 - val_mean_squared_error: 0.1617
#
# Epoch 00176: val_mean_squared_error did not improve from 0.14331
# Epoch 177/2000
# 115/115 [==============================] - 1s 8ms/step - loss: 8.1464 - mean_squared_error: 0.0295 - val_loss: 21.1391 - val_mean_squared_error: 0.1652
#
# Epoch 00177: val_mean_squared_error did not improve from 0.14331
# Epoch 178/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.4406 - mean_squared_error: 0.0325 - val_loss: 21.0182 - val_mean_squared_error: 0.1638
#
# Epoch 00178: val_mean_squared_error did not improve from 0.14331
# Epoch 179/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.4728 - mean_squared_error: 0.0328 - val_loss: 21.1123 - val_mean_squared_error: 0.1648
#
# Epoch 00179: val_mean_squared_error did not improve from 0.14331
# Epoch 180/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.3756 - mean_squared_error: 0.0317 - val_loss: 20.6848 - val_mean_squared_error: 0.1603
#
# Epoch 00180: val_mean_squared_error did not improve from 0.14331
# Epoch 181/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.1963 - mean_squared_error: 0.0297 - val_loss: 20.9922 - val_mean_squared_error: 0.1634
#
# Epoch 00181: val_mean_squared_error did not improve from 0.14331
# Epoch 182/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.3625 - mean_squared_error: 0.0314 - val_loss: 20.4834 - val_mean_squared_error: 0.1581
#
# Epoch 00182: val_mean_squared_error did not improve from 0.14331
# Epoch 183/2000
# 115/115 [==============================] - 1s 6ms/step - loss: 8.1825 - mean_squared_error: 0.0294 - val_loss: 21.1515 - val_mean_squared_error: 0.1650
#
# Epoch 00183: val_mean_squared_error did not improve from 0.14331
# Epoch 184/2000
# 115/115 [==============================] - 1s 6ms/step - loss: 8.4372 - mean_squared_error: 0.0321 - val_loss: 19.6986 - val_mean_squared_error: 0.1498
#
# Epoch 00184: val_mean_squared_error did not improve from 0.14331
# Epoch 185/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.2519 - mean_squared_error: 0.0302 - val_loss: 19.9857 - val_mean_squared_error: 0.1527
#
# Epoch 00185: val_mean_squared_error did not improve from 0.14331
# Epoch 186/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.0962 - mean_squared_error: 0.0286 - val_loss: 20.4961 - val_mean_squared_error: 0.1580
#
# Epoch 00186: val_mean_squared_error did not improve from 0.14331
# Epoch 187/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.7129 - mean_squared_error: 0.0351 - val_loss: 21.4328 - val_mean_squared_error: 0.1678
#
# Epoch 00187: val_mean_squared_error did not improve from 0.14331
# Epoch 188/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.3287 - mean_squared_error: 0.0311 - val_loss: 21.0897 - val_mean_squared_error: 0.1641
#
# Epoch 00188: val_mean_squared_error did not improve from 0.14331
# Epoch 189/2000
# 115/115 [==============================] - 1s 6ms/step - loss: 8.7479 - mean_squared_error: 0.0354 - val_loss: 20.5339 - val_mean_squared_error: 0.1581
#
# Epoch 00189: val_mean_squared_error did not improve from 0.14331
# Epoch 190/2000
# 115/115 [==============================] - 1s 6ms/step - loss: 8.7511 - mean_squared_error: 0.0352 - val_loss: 21.6142 - val_mean_squared_error: 0.1692
#
# Epoch 00190: val_mean_squared_error did not improve from 0.14331
# Epoch 191/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.1621 - mean_squared_error: 0.0289 - val_loss: 20.9612 - val_mean_squared_error: 0.1623
#
# Epoch 00191: val_mean_squared_error did not improve from 0.14331
# Epoch 192/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.8386 - mean_squared_error: 0.0359 - val_loss: 19.7440 - val_mean_squared_error: 0.1497
#
# Epoch 00192: val_mean_squared_error did not improve from 0.14331
# Epoch 193/2000
# 115/115 [==============================] - 1s 6ms/step - loss: 8.2470 - mean_squared_error: 0.0297 - val_loss: 21.1088 - val_mean_squared_error: 0.1639
#
# Epoch 00193: val_mean_squared_error did not improve from 0.14331
# Epoch 194/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.5228 - mean_squared_error: 0.0326 - val_loss: 21.4256 - val_mean_squared_error: 0.1672
#
# Epoch 00194: val_mean_squared_error did not improve from 0.14331
# Epoch 195/2000
# 115/115 [==============================] - 1s 6ms/step - loss: 8.0362 - mean_squared_error: 0.0275 - val_loss: 20.9191 - val_mean_squared_error: 0.1620
#
# Epoch 00195: val_mean_squared_error did not improve from 0.14331
# Epoch 196/2000
# 115/115 [==============================] - 1s 6ms/step - loss: 8.2381 - mean_squared_error: 0.0297 - val_loss: 19.8086 - val_mean_squared_error: 0.1504
#
# Epoch 00196: val_mean_squared_error did not improve from 0.14331
# Epoch 197/2000
# 115/115 [==============================] - 1s 6ms/step - loss: 8.4315 - mean_squared_error: 0.0319 - val_loss: 20.8259 - val_mean_squared_error: 0.1612
#
# Epoch 00197: val_mean_squared_error did not improve from 0.14331
# Epoch 198/2000
# 115/115 [==============================] - 1s 6ms/step - loss: 8.1630 - mean_squared_error: 0.0292 - val_loss: 21.5846 - val_mean_squared_error: 0.1693
#
# Epoch 00198: val_mean_squared_error did not improve from 0.14331
# Epoch 199/2000
# 115/115 [==============================] - 1s 6ms/step - loss: 8.1798 - mean_squared_error: 0.0296 - val_loss: 21.0169 - val_mean_squared_error: 0.1636
#
# Epoch 00199: val_mean_squared_error did not improve from 0.14331
# Epoch 200/2000
# 115/115 [==============================] - 1s 7ms/step - loss: 9.7699 - mean_squared_error: 0.0462 - val_loss: 20.6326 - val_mean_squared_error: 0.1595
#
# Epoch 00200: val_mean_squared_error did not improve from 0.14331
# Epoch 201/2000
# 115/115 [==============================] - 1s 6ms/step - loss: 8.1836 - mean_squared_error: 0.0296 - val_loss: 20.5403 - val_mean_squared_error: 0.1585
#
# Epoch 00201: val_mean_squared_error did not improve from 0.14331
# Epoch 202/2000
# 115/115 [==============================] - 1s 6ms/step - loss: 8.4409 - mean_squared_error: 0.0322 - val_loss: 19.9571 - val_mean_squared_error: 0.1524
#
# Epoch 00202: val_mean_squared_error did not improve from 0.14331
# Epoch 203/2000
# 115/115 [==============================] - 1s 6ms/step - loss: 8.2808 - mean_squared_error: 0.0304 - val_loss: 20.1809 - val_mean_squared_error: 0.1546
#
# Epoch 00203: val_mean_squared_error did not improve from 0.14331
# Epoch 204/2000
# 115/115 [==============================] - 1s 6ms/step - loss: 8.5121 - mean_squared_error: 0.0329 - val_loss: 21.3592 - val_mean_squared_error: 0.1668
#
# Epoch 00204: val_mean_squared_error did not improve from 0.14331
# Epoch 205/2000
# 115/115 [==============================] - 1s 6ms/step - loss: 8.1645 - mean_squared_error: 0.0292 - val_loss: 20.3567 - val_mean_squared_error: 0.1562
#
# Epoch 00205: val_mean_squared_error did not improve from 0.14331
# Epoch 206/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.1194 - mean_squared_error: 0.0288 - val_loss: 20.5458 - val_mean_squared_error: 0.1582
#
# Epoch 00206: val_mean_squared_error did not improve from 0.14331
# Epoch 207/2000
# ...
#
# Epoch 00526: val_mean_squared_error did not improve from 0.14331
# Epoch 527/2000
# 115/115 [==============================] - 0s 4ms/step - loss: 8.2326 - mean_squared_error: 0.0304 - val_loss: 20.4939 - val_mean_squared_error: 0.1584
#
# Epoch 00527: val_mean_squared_error did not improve from 0.14331
# Epoch 528/2000
# 115/115 [==============================] - 0s 4ms/step - loss: 8.1152 - mean_squared_error: 0.0292 - val_loss: 20.3493 - val_mean_squared_error: 0.1568
#
# Epoch 00528: val_mean_squared_error did not improve from 0.14331
# Epoch 529/2000
# 115/115 [==============================] - 0s 4ms/step - loss: 8.6433 - mean_squared_error: 0.0347 - val_loss: 20.2573 - val_mean_squared_error: 0.1557
#
# Epoch 00529: val_mean_squared_error did not improve from 0.14331
# Epoch 530/2000
# 115/115 [==============================] - 0s 4ms/step - loss: 8.6637 - mean_squared_error: 0.0348 - val_loss: 20.7726 - val_mean_squared_error: 0.1610
#
# Epoch 00530: val_mean_squared_error did not improve from 0.14331
# Epoch 531/2000
# 115/115 [==============================] - 0s 4ms/step - loss: 8.0947 - mean_squared_error: 0.0288 - val_loss: 21.2431 - val_mean_squared_error: 0.1658
#
# Epoch 00531: val_mean_squared_error did not improve from 0.14331
# Epoch 532/2000
# 115/115 [==============================] - 0s 4ms/step - loss: 8.1842 - mean_squared_error: 0.0297 - val_loss: 20.4275 - val_mean_squared_error: 0.1574
#
# Epoch 00532: val_mean_squared_error did not improve from 0.14331
# Epoch 533/2000
# 115/115 [==============================] - 1s 4ms/step - loss: 8.5585 - mean_squared_error: 0.0336 - val_loss: 20.8534 - val_mean_squared_error: 0.1618
#
# Epoch 00533: val_mean_squared_error did not improve from 0.14331
# Epoch 534/2000
# 115/115 [==============================] - 1s 4ms/step - loss: 8.3856 - mean_squared_error: 0.0318 - val_loss: 22.2182 - val_mean_squared_error: 0.1761
#
# Epoch 00534: val_mean_squared_error did not improve from 0.14331
# Epoch 535/2000
# 115/115 [==============================] - 0s 4ms/step - loss: 8.0905 - mean_squared_error: 0.0287 - val_loss: 21.3355 - val_mean_squared_error: 0.1669
#
# Epoch 00535: val_mean_squared_error did not improve from 0.14331
# Epoch 536/2000
# 115/115 [==============================] - 1s 4ms/step - loss: 8.1571 - mean_squared_error: 0.0294 - val_loss: 20.0957 - val_mean_squared_error: 0.1540
#
# Epoch 00536: val_mean_squared_error did not improve from 0.14331
# Epoch 537/2000
# 115/115 [==============================] - 0s 4ms/step - loss: 8.4880 - mean_squared_error: 0.0328 - val_loss: 21.2152 - val_mean_squared_error: 0.1657
#
# Epoch 00537: val_mean_squared_error did not improve from 0.14331
# Epoch 538/2000
# 115/115 [==============================] - 1s 4ms/step - loss: 8.4732 - mean_squared_error: 0.0327 - val_loss: 21.2313 - val_mean_squared_error: 0.1658
#
# Epoch 00538: val_mean_squared_error did not improve from 0.14331
# Epoch 539/2000
# 115/115 [==============================] - 0s 4ms/step - loss: 8.3457 - mean_squared_error: 0.0313 - val_loss: 20.7581 - val_mean_squared_error: 0.1608
#
# Epoch 00539: val_mean_squared_error did not improve from 0.14331
# Epoch 540/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.1090 - mean_squared_error: 0.0288 - val_loss: 20.7951 - val_mean_squared_error: 0.1611
#
# Epoch 00540: val_mean_squared_error did not improve from 0.14331
# Epoch 541/2000
# 115/115 [==============================] - 0s 4ms/step - loss: 8.2455 - mean_squared_error: 0.0301 - val_loss: 21.0804 - val_mean_squared_error: 0.1640
#
# Epoch 00541: val_mean_squared_error did not improve from 0.14331
# Epoch 542/2000
# 115/115 [==============================] - 0s 4ms/step - loss: 8.3664 - mean_squared_error: 0.0314 - val_loss: 21.2589 - val_mean_squared_error: 0.1659
#
# Epoch 00542: val_mean_squared_error did not improve from 0.14331
# Epoch 543/2000
# 115/115 [==============================] - 0s 4ms/step - loss: 8.5644 - mean_squared_error: 0.0335 - val_loss: 21.1828 - val_mean_squared_error: 0.1651
#
# Epoch 00543: val_mean_squared_error did not improve from 0.14331
# Epoch 544/2000
# 115/115 [==============================] - 0s 4ms/step - loss: 8.0976 - mean_squared_error: 0.0287 - val_loss: 20.7014 - val_mean_squared_error: 0.1602
#
# Epoch 00544: val_mean_squared_error did not improve from 0.14331
# Epoch 545/2000
# 115/115 [==============================] - 0s 4ms/step - loss: 8.1346 - mean_squared_error: 0.0292 - val_loss: 21.5455 - val_mean_squared_error: 0.1691
#
# Epoch 00545: val_mean_squared_error did not improve from 0.14331
# Epoch 546/2000
# 115/115 [==============================] - 0s 4ms/step - loss: 9.0576 - mean_squared_error: 0.0388 - val_loss: 20.8828 - val_mean_squared_error: 0.1621
#
# Epoch 00546: val_mean_squared_error did not improve from 0.14331
# Epoch 547/2000
# 115/115 [==============================] - 0s 4ms/step - loss: 8.0757 - mean_squared_error: 0.0285 - val_loss: 20.4111 - val_mean_squared_error: 0.1572
#
# Epoch 00547: val_mean_squared_error did not improve from 0.14331
# Epoch 548/2000
# 115/115 [==============================] - 0s 4ms/step - loss: 8.0850 - mean_squared_error: 0.0285 - val_loss: 20.6555 - val_mean_squared_error: 0.1598
#
# Epoch 00548: val_mean_squared_error did not improve from 0.14331
# Epoch 549/2000
# 115/115 [==============================] - 0s 4ms/step - loss: 8.0217 - mean_squared_error: 0.0279 - val_loss: 20.6349 - val_mean_squared_error: 0.1597
#
# Epoch 00549: val_mean_squared_error did not improve from 0.14331
# Epoch 550/2000
# 115/115 [==============================] - 0s 4ms/step - loss: 8.3662 - mean_squared_error: 0.0317 - val_loss: 20.4900 - val_mean_squared_error: 0.1584
#
# Epoch 00550: val_mean_squared_error did not improve from 0.14331
# Epoch 551/2000
# 115/115 [==============================] - 0s 4ms/step - loss: 8.3849 - mean_squared_error: 0.0319 - val_loss: 20.7002 - val_mean_squared_error: 0.1607
#
# Epoch 00551: val_mean_squared_error did not improve from 0.14331
# Epoch 552/2000
# 115/115 [==============================] - 0s 4ms/step - loss: 8.1713 - mean_squared_error: 0.0297 - val_loss: 21.4738 - val_mean_squared_error: 0.1688
#
# Epoch 00552: val_mean_squared_error did not improve from 0.14331
# Epoch 553/2000
# 115/115 [==============================] - 0s 4ms/step - loss: 8.1062 - mean_squared_error: 0.0290 - val_loss: 20.7336 - val_mean_squared_error: 0.1611
#
# Epoch 00553: val_mean_squared_error did not improve from 0.14331
# Epoch 554/2000
# 115/115 [==============================] - 0s 4ms/step - loss: 8.5136 - mean_squared_error: 0.0333 - val_loss: 20.8058 - val_mean_squared_error: 0.1617
#
# Epoch 00554: val_mean_squared_error did not improve from 0.14331
# Epoch 555/2000
# 115/115 [==============================] - 0s 4ms/step - loss: 8.1986 - mean_squared_error: 0.0300 - val_loss: 20.3695 - val_mean_squared_error: 0.1571
#
# Epoch 00555: val_mean_squared_error did not improve from 0.14331
# Epoch 556/2000
# 115/115 [==============================] - 0s 4ms/step - loss: 8.4964 - mean_squared_error: 0.0331 - val_loss: 20.0388 - val_mean_squared_error: 0.1536
#
# Epoch 00556: val_mean_squared_error did not improve from 0.14331
# Epoch 557/2000
# 115/115 [==============================] - 0s 4ms/step - loss: 8.4435 - mean_squared_error: 0.0324 - val_loss: 20.0852 - val_mean_squared_error: 0.1539
#
# Epoch 00557: val_mean_squared_error did not improve from 0.14331
# Epoch 558/2000
# 115/115 [==============================] - 0s 4ms/step - loss: 8.4131 - mean_squared_error: 0.0321 - val_loss: 21.8246 - val_mean_squared_error: 0.1719
#
# Epoch 00558: val_mean_squared_error did not improve from 0.14331
# Epoch 559/2000
# 115/115 [==============================] - 1s 4ms/step - loss: 9.0199 - mean_squared_error: 0.0382 - val_loss: 21.0712 - val_mean_squared_error: 0.1640
#
# Epoch 00559: val_mean_squared_error did not improve from 0.14331
# Epoch 560/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.3588 - mean_squared_error: 0.0312 - val_loss: 20.3585 - val_mean_squared_error: 0.1565
#
# Epoch 00560: val_mean_squared_error did not improve from 0.14331
# Epoch 561/2000
# 115/115 [==============================] - 0s 4ms/step - loss: 8.2709 - mean_squared_error: 0.0302 - val_loss: 21.1505 - val_mean_squared_error: 0.1647
#
# Epoch 00561: val_mean_squared_error did not improve from 0.14331
# Epoch 562/2000
# 115/115 [==============================] - 1s 6ms/step - loss: 8.2433 - mean_squared_error: 0.0299 - val_loss: 20.5530 - val_mean_squared_error: 0.1584
#
# Epoch 00562: val_mean_squared_error did not improve from 0.14331
# Epoch 563/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.5386 - mean_squared_error: 0.0329 - val_loss: 20.2179 - val_mean_squared_error: 0.1549
#
# Epoch 00563: val_mean_squared_error did not improve from 0.14331
# Epoch 564/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.8467 - mean_squared_error: 0.0363 - val_loss: 19.5190 - val_mean_squared_error: 0.1476
#
# Epoch 00564: val_mean_squared_error did not improve from 0.14331
# Epoch 565/2000
# 115/115 [==============================] - 0s 4ms/step - loss: 8.4203 - mean_squared_error: 0.0317 - val_loss: 21.4910 - val_mean_squared_error: 0.1680
#
# Epoch 00565: val_mean_squared_error did not improve from 0.14331
# Epoch 566/2000
# 115/115 [==============================] - 0s 4ms/step - loss: 8.1714 - mean_squared_error: 0.0290 - val_loss: 22.1471 - val_mean_squared_error: 0.1748
#
# Epoch 00566: val_mean_squared_error did not improve from 0.14331
# Epoch 567/2000
# 115/115 [==============================] - 0s 4ms/step - loss: 7.9971 - mean_squared_error: 0.0272 - val_loss: 21.7173 - val_mean_squared_error: 0.1704
#
# Epoch 00567: val_mean_squared_error did not improve from 0.14331
# Epoch 568/2000
# 115/115 [==============================] - 0s 4ms/step - loss: 8.4611 - mean_squared_error: 0.0320 - val_loss: 21.8070 - val_mean_squared_error: 0.1714
#
# Epoch 00568: val_mean_squared_error did not improve from 0.14331
# Epoch 569/2000
# 115/115 [==============================] - 0s 4ms/step - loss: 8.1125 - mean_squared_error: 0.0285 - val_loss: 21.1833 - val_mean_squared_error: 0.1649
#
# Epoch 00569: val_mean_squared_error did not improve from 0.14331
# Epoch 570/2000
# 115/115 [==============================] - 0s 4ms/step - loss: 8.1909 - mean_squared_error: 0.0294 - val_loss: 21.2689 - val_mean_squared_error: 0.1659
#
# Epoch 00570: val_mean_squared_error did not improve from 0.14331
# Epoch 571/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.1317 - mean_squared_error: 0.0289 - val_loss: 21.9754 - val_mean_squared_error: 0.1734
#
# Epoch 00571: val_mean_squared_error did not improve from 0.14331
# Epoch 572/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.1081 - mean_squared_error: 0.0288 - val_loss: 20.8082 - val_mean_squared_error: 0.1614
#
# Epoch 00572: val_mean_squared_error did not improve from 0.14331
# Epoch 573/2000
# 115/115 [==============================] - 1s 6ms/step - loss: 8.4535 - mean_squared_error: 0.0325 - val_loss: 20.9344 - val_mean_squared_error: 0.1628
#
# Epoch 00573: val_mean_squared_error did not improve from 0.14331
# Epoch 574/2000
# 115/115 [==============================] - 1s 6ms/step - loss: 8.5549 - mean_squared_error: 0.0337 - val_loss: 20.3156 - val_mean_squared_error: 0.1564
#
# Epoch 00574: val_mean_squared_error did not improve from 0.14331
# Epoch 575/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.2605 - mean_squared_error: 0.0306 - val_loss: 20.8489 - val_mean_squared_error: 0.1620
#
# Epoch 00575: val_mean_squared_error did not improve from 0.14331
# Epoch 576/2000
# 115/115 [==============================] - 1s 6ms/step - loss: 8.1027 - mean_squared_error: 0.0289 - val_loss: 20.4826 - val_mean_squared_error: 0.1582
#
# Epoch 00576: val_mean_squared_error did not improve from 0.14331
# Epoch 577/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.1343 - mean_squared_error: 0.0294 - val_loss: 21.4888 - val_mean_squared_error: 0.1686
#
# Epoch 00577: val_mean_squared_error did not improve from 0.14331
# Epoch 578/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.3187 - mean_squared_error: 0.0313 - val_loss: 22.1312 - val_mean_squared_error: 0.1751
#
# Epoch 00578: val_mean_squared_error did not improve from 0.14331
# Epoch 579/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.1249 - mean_squared_error: 0.0292 - val_loss: 20.6961 - val_mean_squared_error: 0.1601
#
# Epoch 00579: val_mean_squared_error did not improve from 0.14331
# Epoch 580/2000
# 115/115 [==============================] - 1s 4ms/step - loss: 8.3499 - mean_squared_error: 0.0314 - val_loss: 21.9874 - val_mean_squared_error: 0.1734
#
# Epoch 00580: val_mean_squared_error did not improve from 0.14331
# Epoch 581/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.1625 - mean_squared_error: 0.0293 - val_loss: 21.0896 - val_mean_squared_error: 0.1641
#
# Epoch 00581: val_mean_squared_error did not improve from 0.14331
# Epoch 582/2000
# 115/115 [==============================] - 1s 5ms/step - loss: 8.3565 - mean_squared_error: 0.0313 - val_loss: 21.6889 - val_mean_squared_error: 0.1702
#
# Epoch 00582: val_mean_squared_error did not improve from 0.14331
# Epoch 583/2000
#  64/115 [===============>..............] - ETA: 0s - loss: 7.9710 - mean_squared_error: 0.0279
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-5ca02ae3a324> in <module>
#       7     validation_data=(X_exp_val, X_exp_val),
#       8     #batch_size=batch_size,
# ----> 9     callbacks = callbacks
#      10 )
#      11 IPython.display.Audio("beep.mp3", autoplay=True)
#
# ~/anaconda3/envs/lasts_01/lib/python3.6/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1176                                         steps_per_epoch=steps_per_epoch,
#    1177                                         validation_steps=validation_steps,
# -> 1178                                         validation_freq=validation_freq)
#    1179
#    1180     def evaluate(self,
#
# ~/anaconda3/envs/lasts_01/lib/python3.6/site-packages/keras/engine/training_arrays.py in fit_loop(model, fit_function, fit_inputs, out_labels, batch_size, epochs, verbose, callbacks, val_function, val_inputs, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps, validation_freq)
#     202                     ins_batch[i] = ins_batch[i].toarray()
#     203
# --> 204                 outs = fit_function(ins_batch)
#     205                 outs = to_list(outs)
#     206                 for l, o in zip(out_labels, outs):
#
# ~/anaconda3/envs/lasts_01/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2977                     return self._legacy_call(inputs)
#    2978
# -> 2979             return self._call(inputs)
#    2980         else:
#    2981             if py_any(is_tensor(x) for x in inputs):
#
# ~/anaconda3/envs/lasts_01/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2935             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2936         else:
# -> 2937             fetched = self._callable_fn(*array_vals)
#    2938         return fetched[:len(self.outputs)]
#    2939
#
# ~/anaconda3/envs/lasts_01/lib/python3.6/site-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
plot_history(autoencoder.history.history)

# %%
autoencoder.load_weights(parentdir + "/trained_models/synth04/weights/autoencoders/" + "20210121_122859" + "/vae_best_weights.hdf5")

# %%
from joblib import load
params=load(parentdir + "/trained_models/synth03/synth03_vae.joblib")

# %%
plot_reconstruction_vae(X_exp_test[:5], encoder, decoder)

# %%
print(reconstruction_accuracy_vae(X_exp_test, encoder, decoder, pat, check_label=True))
# Out:
# /Users/francesco/github/LASTS/utils.py:86: UserWarning: No instances with the same label of x found.
#   warnings.warn("No instances with the same label of x found.")
# Accuracy: 0.9444444444444444 ± 0.0
# 0.9444444444444444

# %%
from variational_autoencoder import save_model

# %%
save_model(autoencoder, input_shape, latent_dim, autoencoder_kwargs, 
           path=parentdir + "/trained_models/ts_syege/weights/autoencoders/" + "20200723_181036" + "/coffee_vae")
