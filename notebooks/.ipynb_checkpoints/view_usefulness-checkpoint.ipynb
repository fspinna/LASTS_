# %%
import os,sys,inspect
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0,parentdir)

# %%
from joblib import load
from utils import plot_usefulness

# %%
dfs = load(parentdir + "/test_metrics/usefulness_dfs.joblib")

# %%
dfs.keys()
# Out:
# dict_keys(['global_cbf', 'global_coffee', 'global_ecg200', 'global_gunpoint', 'lasts_cbf_knn', 'lasts_cbf_resnet', 'lasts_coffee_knn', 'lasts_coffee_resnet', 'lasts_ecg200_knn', 'lasts_ecg200_resnet', 'lasts_gunpoint_knn', 'lasts_gunpoint_resnet'])

# %%
plot_usefulness(dfs["lasts_cbf_knn"], dfs["global_cbf"], dpi=300)

# %%
plot_usefulness(dfs["lasts_coffee_knn"], dfs["global_coffee"], dataset_label="cof - knn", dpi=300)

# %%
plot_usefulness(dfs["lasts_ecg200_knn"], dfs["global_ecg200"], dataset_label="ecg - knn", dpi=300)

# %%
plot_usefulness(dfs["lasts_gunpoint_knn"], dfs["global_gunpoint"], dataset_label="gun - knn", dpi=300)

# %%
plot_usefulness(dfs["lasts_cbf_resnet"], dfs["global_cbf"], dpi=300)

# %%
plot_usefulness(dfs["lasts_coffee_resnet"], dfs["global_coffee"], dataset_label="cof - resnet", dpi=300)

# %%
plot_usefulness(dfs["lasts_ecg200_resnet"], dfs["global_ecg200"], dataset_label="ecg - resnet", dpi=300)

# %%
plot_usefulness(dfs["lasts_gunpoint_resnet"], dfs["global_gunpoint"], dataset_label="gun - resnet", dpi=300)
