# %%
import os,sys,inspect
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0,parentdir)

# %%
from datasets import build_esr
from blackboxes import build_resnet
import numpy as np
import time
import keras
from blackbox_wrapper import BlackboxWrapper
from variational_autoencoder import build_vae, plot_history
from utils import reconstruction_accuracy
import matplotlib.pyplot as plt
from joblib import dump
# Out:
# Using TensorFlow backend.

# %%
# IMPORT DATASET
random_state = 0
dataset_name = "esr"
dataset_dir = "/trained_models/" + dataset_name + "/"

(X_train, y_train, X_val, y_val, 
 X_test, y_test, X_exp_train, y_exp_train, 
 X_exp_val, y_exp_val, X_exp_test, y_exp_test) = build_esr(path=parentdir+"/datasets/esr/", random_state = random_state)
# Out:
# X SHAPE:  (4600, 178, 1)
# y SHAPE:  (4600,)
#
# CLASSES BALANCE
# 0 :  0.5
# 1 :  0.5
# SHAPES:
# BLACKBOX TRAINING SET:  (2060, 178, 1)
# BLACKBOX VALIDATION SET:  (516, 178, 1)
# BLACKBOX TEST SET:  (920, 178, 1)
# EXPLANATION TRAINING SET:  (706, 178, 1)
# EXPLANATION VALIDATION SET:  (177, 178, 1)
# EXPLANATION TEST SET:  (221, 178, 1)

# %%
input_shape = X_train.shape[1:]
n_timesteps = input_shape[0]
n_classes = len(np.unique(y_train))

# %%
for i in np.unique(y_train):
    plt.figure(figsize=(20,3))
    by_label = y_train == i
    plt.plot(X_train[by_label][:,:,0].T, c="gray", alpha=0.5)
    plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
scaler.fit(X_train[:,:,0])
# Out:
# MinMaxScaler(copy=True, feature_range=(0, 1))

# %%
X_train_s = scaler.transform(X_train[:,:,0])[:,:,np.newaxis]

# %%
X_train_rev = scaler.inverse_transform(X_train_s[:,:,0])

# %%
plt.plot(X_train_s[0].ravel())

# %%
plt.plot(X_train[0].ravel())
plt.plot(X_train_rev[0].ravel())

# %% [markdown]
# ### Blackbox

# %%
"""resnet = build_resnet(n_timesteps, n_classes)"""
# Out:
# WARNING:tensorflow:From /Users/francesco/anaconda3/envs/tesi/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
"""save_folder = parentdir + dataset_dir + "weights/blackboxes/" + time.strftime("%Y%m%d_%H%M%S") + "/"
os.makedirs(save_folder)

reduce_lr = keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=50, min_lr=0.0001)
file_path = save_folder + "blackbox_resnet_" + "_best_weights_+{val_acc:.2f}_.hdf5" 

model_checkpoint = keras.callbacks.ModelCheckpoint(filepath=file_path, 
                                                   monitor='val_acc', 
                                                   save_weights_only = True, 
                                                   verbose = 1,
                                                   save_best_only=True)


callbacks = [reduce_lr, model_checkpoint]

batch_size = 16
mini_batch_size = int(min(X_train.shape[0]/10, batch_size))"""

# %%
"""resnet.fit(
    X_train, 
    y_train, 
    epochs=10, 
    batch_size=mini_batch_size, 
    callbacks = callbacks, 
    validation_data=(X_val, y_val)
)"""
# Out:
# Train on 537 samples, validate on 135 samples
# Epoch 1/10
# 537/537 [==============================] - 26s 48ms/step - loss: 0.6811 - acc: 0.7337 - val_loss: 1.7189 - val_acc: 0.6667
#
# Epoch 00001: val_acc improved from -inf to 0.66667, saving model to /Users/francesco/github/LASTS/trained_models/rnd_blobs/weights/blackboxes/20200713_165914/blackbox_resnet__best_weights_+0.67_.hdf5
# Epoch 2/10
# 537/537 [==============================] - 10s 18ms/step - loss: 0.3095 - acc: 0.9143 - val_loss: 2.8913 - val_acc: 0.6667
#
# Epoch 00002: val_acc did not improve from 0.66667
# Epoch 3/10
# 537/537 [==============================] - 10s 19ms/step - loss: 0.2021 - acc: 0.9423 - val_loss: 0.9808 - val_acc: 0.8296
#
# Epoch 00003: val_acc improved from 0.66667 to 0.82963, saving model to /Users/francesco/github/LASTS/trained_models/rnd_blobs/weights/blackboxes/20200713_165914/blackbox_resnet__best_weights_+0.83_.hdf5
# Epoch 4/10
# 537/537 [==============================] - 11s 21ms/step - loss: 0.1502 - acc: 0.9590 - val_loss: 1.6914 - val_acc: 0.6074
#
# Epoch 00004: val_acc did not improve from 0.82963
# Epoch 5/10
# 537/537 [==============================] - 12s 21ms/step - loss: 0.0398 - acc: 0.9944 - val_loss: 0.0032 - val_acc: 1.0000
#
# Epoch 00005: val_acc improved from 0.82963 to 1.00000, saving model to /Users/francesco/github/LASTS/trained_models/rnd_blobs/weights/blackboxes/20200713_165914/blackbox_resnet__best_weights_+1.00_.hdf5
# Epoch 6/10
# 537/537 [==============================] - 13s 23ms/step - loss: 0.0350 - acc: 0.9926 - val_loss: 1.2122 - val_acc: 0.8296
#
# Epoch 00006: val_acc did not improve from 1.00000
# Epoch 7/10
# 537/537 [==============================] - 10s 19ms/step - loss: 0.0656 - acc: 0.9832 - val_loss: 1.9300 - val_acc: 0.8296
#
# Epoch 00007: val_acc did not improve from 1.00000
# Epoch 8/10
# 537/537 [==============================] - 11s 20ms/step - loss: 0.0343 - acc: 0.9963 - val_loss: 0.0514 - val_acc: 0.9778
#
# Epoch 00008: val_acc did not improve from 1.00000
# Epoch 9/10
# 537/537 [==============================] - 10s 19ms/step - loss: 0.0355 - acc: 0.9926 - val_loss: 0.1118 - val_acc: 0.9407
#
# Epoch 00009: val_acc did not improve from 1.00000
# Epoch 10/10
# 537/537 [==============================] - 10s 19ms/step - loss: 0.0308 - acc: 0.9963 - val_loss: 1.4999 - val_acc: 0.8370
#
# Epoch 00010: val_acc did not improve from 1.00000

# %%
"""resnet.load_weights("EpilepticSeizureRecognition_blackbox_resnet_20200105_233014_best_weights_+0.99_.hdf5")"""

# %%
"""resnet.save("esr_resnet.h5")"""

# %%
resnet = keras.models.load_model(parentdir + dataset_dir + dataset_name + "_resnet.h5")

# %%
resnet.evaluate(X_test, y_test)
# Out:
# 920/920 [==============================] - 17s 18ms/step
# [0.052825441689270995, 0.97826087474823]

# %%
blackbox = BlackboxWrapper(resnet, 3, 2)

# %% [markdown]
# ### VAE

# %%
latent_dim = 30

autoencoder_kwargs = {
    "filters": [64, 64, 64, 64, 64, 64, 64, 64],
    "kernel_size": [3, 3, 3, 3, 3, 3, 3, 3],
    "padding": ["same", "same", "same", "same", "same", "same", "same", "same"],
    "activation": ["relu", "relu", "relu", "relu", "relu", "relu", "relu", "relu"],
    "pooling": [1, 1, 1, 1, 1, 1, 1, 1],
    "n_layers": 8,
    "optimizer": "adam",
    "n_layers_residual": None,
    "batch_normalization": None
}

model_kwargs = {"input_shape": input_shape, "latent_dim": latent_dim, "autoencoder_kwargs": autoencoder_kwargs}

# %%
encoder, decoder, autoencoder = build_vae(input_shape, latent_dim, autoencoder_kwargs)
# Out:
# WARNING:tensorflow:From /Users/francesco/anaconda3/envs/env_test/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Model: "Encoder"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 178, 1)       0
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 178, 64)      256         input_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 178, 64)      0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_1 (MaxPooling1D)  (None, 178, 64)      0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 178, 64)      12352       max_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 178, 64)      0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_2 (MaxPooling1D)  (None, 178, 64)      0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 178, 64)      12352       max_pooling1d_2[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 178, 64)      0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_3 (MaxPooling1D)  (None, 178, 64)      0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 178, 64)      12352       max_pooling1d_3[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 178, 64)      0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_4 (MaxPooling1D)  (None, 178, 64)      0           activation_4[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 178, 64)      12352       max_pooling1d_4[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 178, 64)      0           conv1d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_5 (MaxPooling1D)  (None, 178, 64)      0           activation_5[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 178, 64)      12352       max_pooling1d_5[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 178, 64)      0           conv1d_6[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_6 (MaxPooling1D)  (None, 178, 64)      0           activation_6[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 178, 64)      12352       max_pooling1d_6[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 178, 64)      0           conv1d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_7 (MaxPooling1D)  (None, 178, 64)      0           activation_7[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 178, 64)      12352       max_pooling1d_7[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 178, 64)      0           conv1d_8[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_8 (MaxPooling1D)  (None, 178, 64)      0           activation_8[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 178, 1)       65          max_pooling1d_8[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 178)          0           conv1d_9[0][0]
# __________________________________________________________________________________________________
# z_mean (Dense)                  (None, 30)           5370        flatten_1[0][0]
# __________________________________________________________________________________________________
# z_log_var (Dense)               (None, 30)           5370        flatten_1[0][0]
# __________________________________________________________________________________________________
# kl_divergence_layer_1 (KLDiverg [(None, 30), (None,  0           z_mean[0][0]
#                                                                  z_log_var[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 30)           0           kl_divergence_layer_1[0][1]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, 30)           0
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 30)           0           lambda_1[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 30)           0           kl_divergence_layer_1[0][0]
#                                                                  multiply_1[0][0]
# ==================================================================================================
# Total params: 97,525
# Trainable params: 97,525
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "Decoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# z_sampling (InputLayer)      (None, 30)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 178)               5518
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 178, 1)            0
# _________________________________________________________________
# conv1d_10 (Conv1D)           (None, 178, 64)           256
# _________________________________________________________________
# activation_9 (Activation)    (None, 178, 64)           0
# _________________________________________________________________
# up_sampling1d_1 (UpSampling1 (None, 178, 64)           0
# _________________________________________________________________
# conv1d_11 (Conv1D)           (None, 178, 64)           12352
# _________________________________________________________________
# activation_10 (Activation)   (None, 178, 64)           0
# _________________________________________________________________
# up_sampling1d_2 (UpSampling1 (None, 178, 64)           0
# _________________________________________________________________
# conv1d_12 (Conv1D)           (None, 178, 64)           12352
# _________________________________________________________________
# activation_11 (Activation)   (None, 178, 64)           0
# _________________________________________________________________
# up_sampling1d_3 (UpSampling1 (None, 178, 64)           0
# _________________________________________________________________
# conv1d_13 (Conv1D)           (None, 178, 64)           12352
# _________________________________________________________________
# activation_12 (Activation)   (None, 178, 64)           0
# _________________________________________________________________
# up_sampling1d_4 (UpSampling1 (None, 178, 64)           0
# _________________________________________________________________
# conv1d_14 (Conv1D)           (None, 178, 64)           12352
# _________________________________________________________________
# activation_13 (Activation)   (None, 178, 64)           0
# _________________________________________________________________
# up_sampling1d_5 (UpSampling1 (None, 178, 64)           0
# _________________________________________________________________
# conv1d_15 (Conv1D)           (None, 178, 64)           12352
# _________________________________________________________________
# activation_14 (Activation)   (None, 178, 64)           0
# _________________________________________________________________
# up_sampling1d_6 (UpSampling1 (None, 178, 64)           0
# _________________________________________________________________
# conv1d_16 (Conv1D)           (None, 178, 64)           12352
# _________________________________________________________________
# activation_15 (Activation)   (None, 178, 64)           0
# _________________________________________________________________
# up_sampling1d_7 (UpSampling1 (None, 178, 64)           0
# _________________________________________________________________
# conv1d_17 (Conv1D)           (None, 178, 64)           12352
# _________________________________________________________________
# activation_16 (Activation)   (None, 178, 64)           0
# _________________________________________________________________
# up_sampling1d_8 (UpSampling1 (None, 178, 64)           0
# _________________________________________________________________
# conv1d_18 (Conv1D)           (None, 178, 1)            65
# =================================================================
# Total params: 92,303
# Trainable params: 92,303
# Non-trainable params: 0
# _________________________________________________________________
# Model: "VAE"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            (None, 178, 1)       0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            (None, 30)           0
# __________________________________________________________________________________________________
# Encoder (Model)                 (None, 30)           97525       input_3[0][0]
#                                                                  input_4[0][0]
# __________________________________________________________________________________________________
# Decoder (Model)                 (None, 178, 1)       92303       Encoder[1][0]
# ==================================================================================================
# Total params: 189,828
# Trainable params: 189,828
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
save_folder = parentdir + dataset_dir + "weights/autoencoders/" + time.strftime("%Y%m%d_%H%M%S") + "/"
os.makedirs(save_folder)
dump(model_kwargs, save_folder + "model_kwargs.joblib")


reduce_lr = keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=200, min_lr=0.0001)
file_path = save_folder + "vae" + "_best_weights_+{val_loss:.2f}_.hdf5" 

model_checkpoint = keras.callbacks.ModelCheckpoint(filepath=file_path, 
                                                   monitor='val_loss', 
                                                   save_weights_only = True, 
                                                   verbose = 1,
                                                   save_best_only=True)

callbacks = [reduce_lr, model_checkpoint]

# %%
batch_size = 178
epochs=2000
autoencoder.fit(
    X_exp_train, 
    X_exp_train, 
    epochs=epochs, 
    validation_data=(X_exp_val, X_exp_val), 
    #batch_size=batch_size,
    #callbacks = callbacks
)
# Out:
# Train on 706 samples, validate on 177 samples
# Epoch 1/2000
# 160/706 [=====>........................] - ETA: 1:17 - loss: 665229.5203 - mse: 57082.1445
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-7d47a26c7903> in <module>
#       5     X_exp_train,
#       6     epochs=epochs,
# ----> 7     validation_data=(X_exp_val, X_exp_val),
#       8     #batch_size=batch_size,
#       9     #callbacks = callbacks
#
# ~/anaconda3/envs/env_test/lib/python3.7/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1237                                         steps_per_epoch=steps_per_epoch,
#    1238                                         validation_steps=validation_steps,
# -> 1239                                         validation_freq=validation_freq)
#    1240
#    1241     def evaluate(self,
#
# ~/anaconda3/envs/env_test/lib/python3.7/site-packages/keras/engine/training_arrays.py in fit_loop(model, fit_function, fit_inputs, out_labels, batch_size, epochs, verbose, callbacks, val_function, val_inputs, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq)
#     194                     ins_batch[i] = ins_batch[i].toarray()
#     195
# --> 196                 outs = fit_function(ins_batch)
#     197                 outs = to_list(outs)
#     198                 for l, o in zip(out_labels, outs):
#
# ~/anaconda3/envs/env_test/lib/python3.7/site-packages/tensorflow_core/python/keras/backend.py in __call__(self, inputs)
#    3578
#    3579     fetched = self._callable_fn(*array_vals,
# -> 3580                                 run_metadata=self.run_metadata)
#    3581     self._call_fetch_callbacks(fetched[-len(self._fetches):])
#    3582     output_structure = nest.pack_sequence_as(
#
# ~/anaconda3/envs/env_test/lib/python3.7/site-packages/tensorflow_core/python/client/session.py in __call__(self, *args, **kwargs)
#    1470         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1471                                                self._handle, args,
# -> 1472                                                run_metadata_ptr)
#    1473         if run_metadata:
#    1474           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
plot_history(autoencoder.history.history)

# %%
reconstruction_accuracy(X_exp_test, encoder, decoder, blackbox, repeat=10)
# Out:
# Accuracy: 0.6916666666666667 ± 0.06911030724791514
# 0.6916666666666667

# %%
reconstruction_accuracy(X_exp_test, encoder, decoder, blackbox, repeat=10)
# Out:
# Accuracy: 0.7994444444444447 ± 0.039641526424747456
# 0.7994444444444447
