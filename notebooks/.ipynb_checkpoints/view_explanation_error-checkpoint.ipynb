# %%
import os,sys,inspect
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0,parentdir)

# %%
from joblib import load
from utils import boxplot_from_df
import pandas as pd

# %%
df = pd.read_csv(parentdir + "/test_metrics/explanation_error.csv", sep=";")

# %%
boxplot_from_df(df[["lasts_explanation_error", "shap_absexplanation_error"]], 
                labels=["lasts", "shap"], dpi=300, figsize=(6,4), ylabel="incorrectness", fontsize=25)
