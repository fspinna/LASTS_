# %%
import os,sys,inspect
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0,parentdir)

# %%
from joblib import load
from utils import boxplot_from_df, baseline_error
import pandas as pd
from lasts import load_multiple_lasts
import numpy as np
from sklearn.neighbors import NearestNeighbors
from collections import defaultdict
from scipy.spatial.distance import cdist
from sklearn.metrics import mean_absolute_error
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.
# /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/sklearn/utils/deprecation.py:143: FutureWarning: The sklearn.cluster.k_means_ module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.cluster. Anything that cannot be imported from sklearn.cluster is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/sklearn/utils/deprecation.py:143: FutureWarning: The sklearn.neighbors.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.neighbors. Anything that cannot be imported from sklearn.neighbors is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/sklearn/utils/deprecation.py:143: FutureWarning: The sklearn.ensemble.bagging module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.ensemble. Anything that cannot be imported from sklearn.ensemble is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/sklearn/utils/deprecation.py:143: FutureWarning: The sklearn.ensemble.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.ensemble. Anything that cannot be imported from sklearn.ensemble is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/sklearn/utils/deprecation.py:143: FutureWarning: The sklearn.ensemble.forest module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.ensemble. Anything that cannot be imported from sklearn.ensemble is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/sklearn/utils/deprecation.py:143: FutureWarning: The sklearn.utils.testing module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.utils. Anything that cannot be imported from sklearn.utils is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/sklearn/utils/deprecation.py:143: FutureWarning: The sklearn.metrics.classification module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.metrics. Anything that cannot be imported from sklearn.metrics is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
from utils import boxplot_from_df

# %%
dict_stab = load(parentdir + "/test_metrics/precal_predictions.joblib")
dict_stab["ecg200_resnet"] = dict_stab["ecg200_resnet"][:100]

# %%
lasts_cbf_knn = load_multiple_lasts(parentdir + "/saved/knn/cbf/matched_uniform_saxdt", simple_load=True)
lasts_cbf_resnet = load_multiple_lasts(parentdir + "/saved/resnet/cbf/matched_uniform_saxdt", simple_load=True)

lasts_coffee_knn = load_multiple_lasts(parentdir + "/saved/knn/coffee/matched_uniform_saxdt", simple_load=True)
lasts_coffee_resnet = load_multiple_lasts(parentdir + "/saved/resnet/coffee/matched_uniform_saxdt", simple_load=True)

lasts_ecg200_knn = load_multiple_lasts(parentdir + "/saved/knn/ecg200/matched_uniform_saxdt", simple_load=True)
lasts_ecg200_resnet = load_multiple_lasts(parentdir + "/saved/resnet/ecg200/matched_uniform_saxdt", simple_load=True)

lasts_gunpoint_knn = load_multiple_lasts(parentdir + "/saved/knn/gunpoint/matched_uniform_saxdt", simple_load=True)
lasts_gunpoint_resnet = load_multiple_lasts(parentdir + "/saved/resnet/gunpoint/matched_uniform_saxdt", simple_load=True)

lasts_lists = [lasts_cbf_knn, lasts_cbf_resnet, lasts_coffee_knn, lasts_coffee_resnet, lasts_ecg200_knn,
               lasts_ecg200_resnet, lasts_gunpoint_knn, lasts_gunpoint_resnet]
names = ["cbf_knn", "cbf_resnet", "coffee_knn", "coffee_resnet", "ecg200_knn", "ecg200_resnet",
         "gunpoint_knn", "gunpoint_resnet"]
# Out:
# /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/keras/engine/saving.py:310: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
# WARNING:tensorflow:From /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %%
df_shap = pd.read_csv(parentdir + "/test_metrics/stability_shap_manifest.csv", sep=";")
columns = list(dict_stab.keys())
for i in range(len(columns)):
    columns[i] = columns[i]+"_shap"
df_shap.columns=columns

# %%
verbose=True
latent=False
compute_lasts=True
divide_by_baseline=False
lasts_kwargs=dict()
combination_name="prova"
debug=False
ignore_mismatch=True

# %%
instabilities = defaultdict(list)
for i, key in enumerate(dict_stab):
    combination = dict_stab[key]
    X = list()
    Z = list()
    for lasts_ in lasts_lists[i]:
        X.append(lasts_.x.ravel())
        Z.append(lasts_.z.ravel())
    X = np.array(X)[:, :, np.newaxis]
    Z = np.array(Z)
    print(X.shape, Z.shape)
    if latent:
        nbrs = NearestNeighbors(n_neighbors=2, algorithm='ball_tree').fit(Z)
        distances, idxs = nbrs.kneighbors(Z)
    else:
        nbrs = NearestNeighbors(n_neighbors=2, algorithm='ball_tree').fit(X[:, :, 0])
        distances, idxs = nbrs.kneighbors(X[:, :, 0])

    if compute_lasts:
        if verbose:
            print("Computing LASTS instability... ", sep="")
        for i, idx in enumerate(idxs):
            #print(i, idx)
            instability_lasts_ = instability_lasts(
                combination[i],
                combination[idx[-1]],  # the first value is the idx of the instance itself
                ignore_mismatch=ignore_mismatch,
                divide_by_baseline=divide_by_baseline,
                debug=debug,
                **lasts_kwargs
            )
            if instability_lasts_ is not np.nan:
                instabilities[key].append(instability_lasts_)
        if verbose:
            print("Done!")
# Out:
# (36, 128, 1) (36, 2)
# Computing LASTS instability...
# Done!
# (36, 128, 1) (36, 2)
# Computing LASTS instability...
# Done!
# (28, 286, 1) (28, 3)
# Computing LASTS instability...
# Done!
# (28, 286, 1) (28, 3)
# Computing LASTS instability...
# Done!
# (100, 96, 1) (100, 4)
# Computing LASTS instability...
# /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/numpy/core/_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/numpy/core/_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/numpy/core/_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/numpy/core/_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/numpy/core/_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/numpy/core/_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/numpy/core/_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/numpy/core/_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/numpy/core/_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/numpy/core/_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/numpy/core/_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/numpy/core/_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/numpy/core/_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/numpy/core/_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/numpy/core/_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/numpy/core/_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/numpy/core/_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/numpy/core/_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/numpy/core/_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/numpy/core/_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Done!
# (100, 96, 1) (100, 4)
# Computing LASTS instability...
# Done!
# (50, 150, 1) (50, 2)
# Computing LASTS instability...
# Done!
# (50, 150, 1) (50, 2)
# Computing LASTS instability...
# Done!
# /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/numpy/core/_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/numpy/core/_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/numpy/core/_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/numpy/core/_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/numpy/core/_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/numpy/core/_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/numpy/core/_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/numpy/core/_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/numpy/core/_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
columns = list(instabilities.keys())
for i in range(len(columns)):
    columns[i] = columns[i]+"_lasts"
df = list()
for key in instabilities:
    df.append(instabilities[key])
df_lasts = pd.DataFrame(df).T
df_lasts.columns = columns
df = pd.concat([df_lasts, df_shap], axis=1)
df = df.reindex(sorted(df.columns), axis=1)
df_columns=list(df.columns)
df = df.apply(lambda x: x.dropna().tolist()).tolist()

# %%
figsize=(20,3)
dpi=300
ylabel="instability"
xticks=["lasts", "shap"]*8
fontsize=20
x_labels = ['cbf-knn', 'cbf-res', 'cof-knn','cof-res', 'ecg-knn', 'ecg-res', 'gun-knn',
            'gun-res']
medianprops = dict(linestyle='-', linewidth=3, color='#8c510a')
meanprops = dict(marker='D', markeredgecolor='#003c30', markerfacecolor='#003c30')
boxprops = dict(linestyle='-', linewidth=3, color='#01665e')
whiskerprops = dict(linestyle='-', linewidth=3, color='#01665e')
capprops = dict(linestyle='-', linewidth=3, color='#01665e')
plt.figure(figsize=(figsize), dpi=dpi)
plt.boxplot(df, medianprops=medianprops, boxprops=boxprops, capprops=capprops, whiskerprops=whiskerprops,
            meanprops=meanprops, showmeans=False, showfliers=False)

#plt.axhline(y=1, color='r', linestyle='--')
plt.xticks(np.array(list(range(16))) + 1, xticks)
plt.ylabel(ylabel, fontsize=fontsize)
x_pos = np.array(list(range(16))) + 1.5
for i in range(16):
    if i%2 == 0:
        plt.text(x_pos[i], plt.gca().get_ylim()[0] - 0.2, x_labels[int(i/2)], fontsize=fontsize, 
                 horizontalalignment="center")
    else:
        plt.axvline(x=x_pos[i], color='black', linestyle='-')
plt.tick_params(axis='both', which='major', labelsize=fontsize)
plt.show()

# %%
len(df[1])
# Out:
# 36

# %%
#count mismatch
from scipy import stats
i=0
while i < len(df):
    print(df_columns[i],df_columns[i+1])
    print(stats.ttest_ind(df[i], df[i+1], equal_var = False))
    print()
    i += 2
# Out:
# cbf_knn_lasts cbf_knn_shap
# Ttest_indResult(statistic=0.05565887949455132, pvalue=0.9558430331239733)
#
# cbf_resnet_lasts cbf_resnet_shap
# Ttest_indResult(statistic=1.5565618483476447, pvalue=0.12412207301638034)
#
# coffee_knn_lasts coffee_knn_shap
# Ttest_indResult(statistic=3.007320058180759, pvalue=0.004415083102909399)
#
# coffee_resnet_lasts coffee_resnet_shap
# Ttest_indResult(statistic=1.846975249790358, pvalue=0.07039989592067589)
#
# ecg200_knn_lasts ecg200_knn_shap
# Ttest_indResult(statistic=-1.294905528091004, pvalue=0.1969091416700189)
#
# ecg200_resnet_lasts ecg200_resnet_shap
# Ttest_indResult(statistic=-0.15955642924204508, pvalue=0.8733961797119421)
#
# gunpoint_knn_lasts gunpoint_knn_shap
# Ttest_indResult(statistic=2.3344323807275034, pvalue=0.021696028639400435)
#
# gunpoint_resnet_lasts gunpoint_resnet_shap
# Ttest_indResult(statistic=-1.3028385271339238, pvalue=0.19568710691076083)

# %%
#ignore mismatch
from scipy import stats
i=0
while i < len(df):
    print(df_columns[i],df_columns[i+1])
    print(stats.ttest_ind(df[i], df[i+1], equal_var = False))
    print()
    i += 2
# Out:
# cbf_knn_lasts cbf_knn_shap
# Ttest_indResult(statistic=-0.1117873876660911, pvalue=0.9113849436008049)
#
# cbf_resnet_lasts cbf_resnet_shap
# Ttest_indResult(statistic=-0.2908964363530893, pvalue=0.772403255396542)
#
# coffee_knn_lasts coffee_knn_shap
# Ttest_indResult(statistic=2.4571471027998424, pvalue=0.01859321401022322)
#
# coffee_resnet_lasts coffee_resnet_shap
# Ttest_indResult(statistic=1.6522415536284363, pvalue=0.105560883767041)
#
# ecg200_knn_lasts ecg200_knn_shap
# Ttest_indResult(statistic=-3.268051353369563, pvalue=0.0012799528499375483)
#
# ecg200_resnet_lasts ecg200_resnet_shap
# Ttest_indResult(statistic=-0.7312767309388589, pvalue=0.46547916815173696)
#
# gunpoint_knn_lasts gunpoint_knn_shap
# Ttest_indResult(statistic=2.0669345558013617, pvalue=0.04162331006760562)
#
# gunpoint_resnet_lasts gunpoint_resnet_shap
# Ttest_indResult(statistic=-1.5612345135599999, pvalue=0.12214403106198306)

# %%
medianprops = dict(linestyle='-', linewidth=3, color='#8c510a')
meanprops = dict(marker='D', markeredgecolor='#003c30', markerfacecolor='#003c30')
boxprops = dict(linestyle='-', linewidth=3, color='#01665e')
whiskerprops = dict(linestyle='-', linewidth=3, color='#01665e')
capprops = dict(linestyle='-', linewidth=3, color='#01665e')
plt.figure(figsize=(figsize), dpi=dpi)
plt.boxplot(df, medianprops=medianprops, boxprops=boxprops, capprops=capprops, whiskerprops=whiskerprops,
            meanprops=meanprops, showmeans=False, showfliers=False)

#plt.axhline(y=1, color='r', linestyle='--')
plt.xticks(np.array(list(range(16))) + 1, xticks)
plt.ylabel(ylabel, fontsize=fontsize)
x_pos = np.array(list(range(16))) + 1.5
for i in range(16):
    if i%2 == 0:
        plt.text(x_pos[i], plt.gca().get_ylim()[0] - 0.2, x_labels[int(i/2)], fontsize=fontsize, 
                 horizontalalignment="center")
    else:
        plt.axvline(x=x_pos[i], color='black', linestyle='-')
plt.tick_params(axis='both', which='major', labelsize=fontsize)
plt.show()

# %%
def instability_lasts(pred_importances1, pred_importances2, ignore_mismatch=False, debug=False, 
                      divide_by_baseline=True):
    cont_errors = list()
    if (pred_importances1[-1].sum() == 0) and (pred_importances2[-1].sum() == 0):
            cont_errors.append(0)
    elif (pred_importances1[-1].sum() == 0) or (pred_importances2[-1].sum() == 0):
        if not ignore_mismatch:
            if divide_by_baseline:
                baseline = baseline_error(pred_importances1[-1])
                if baseline == 0:
                    cont_errors.append(1)
                cont_errors.append(mean_absolute_error(pred_importances1[-1, :], pred_importances2[-1, :]) / baseline_error(pred_importances1[-1]))
            else:
                cont_errors.append(mean_absolute_error(pred_importances1[-1, :], pred_importances2[-1, :]))
    else:
        if divide_by_baseline:
            baseline = baseline_error(pred_importances1[-1])
            if baseline == 0:
                cont_errors.append(1)
            else:
                error = mean_absolute_error(pred_importances1[-1, :], pred_importances2[-1, :]) / baseline_error(pred_importances1[-1])
                cont_errors.append(error)
        else:
            cont_errors.append(mean_absolute_error(pred_importances1[-1, :], pred_importances2[-1, :]))
    errors=list()
    #print(errors)
    pred_importances1 = pred_importances1[:-1]
    pred_importances2 = pred_importances2[:-1]
    if (len(pred_importances1) == 0) and (len(pred_importances2) == 0):
        errors.append(0)
    else:
        if not ignore_mismatch:
            #  doesn't ignore if there is a different number of not-contained subsequences i.e. the surplus vectors will
            #  be matched with all 0's vectors
            mismatch = len(pred_importances1) - len(pred_importances2)
            if mismatch != 0:
                if mismatch > 0:
                    if len(pred_importances2) == 0:
                        pred_importances2 = np.zeros(shape=(abs(mismatch), pred_importances1.shape[1]))
                    else:
                        pred_importances2 = np.append(pred_importances2,
                                                      np.zeros(shape=(abs(mismatch), pred_importances1.shape[1])), axis=0)
                else:
                    if len(pred_importances1) == 0:
                        pred_importances1 = np.zeros(shape=(abs(mismatch), pred_importances1.shape[1]))
                    else:
                        pred_importances1 = np.append(pred_importances1,
                                                      np.zeros(shape=(abs(mismatch), pred_importances1.shape[1])), axis=0)
        else:
            if ((len(pred_importances1) == 0) or (len(pred_importances2) == 0)):
                return np.mean(cont_errors)
        distance_matrix = cdist(pred_importances1, pred_importances2, metric=mean_absolute_error)
        #print(distance_matrix)
        if debug:
            print(distance_matrix)
        while (distance_matrix.shape[1] > 0) and (len(distance_matrix) > 0):
            if debug:
                print(distance_matrix)
            to_delete = np.unravel_index(np.argmin(distance_matrix), shape=distance_matrix.shape)
            if divide_by_baseline:
                baseline = baseline_error(pred_importances1[to_delete[0]])
                if baseline == 0:
                    errors.append(1)  # FIXME: limit case
                else:
                    errors.append(distance_matrix.min() / baseline)
            else:
                errors.append(distance_matrix.min())
            distance_matrix = np.delete(distance_matrix, to_delete[0], axis=0)
            distance_matrix = np.delete(distance_matrix, to_delete[1], axis=1)
    if len(cont_errors) == 0 and len(errors) == 0:
        final_error = np.nan
    elif len(cont_errors) == 0:
        final_error = np.mean(errors)
    elif len(errors) == 0:
        final_error = np.mean(cont_errors)
    else:
        final_error = (np.mean(cont_errors) + np.mean(errors))/2
    return final_error

# %%
def instability_lasts(pred_importances1, pred_importances2, ignore_mismatch=False, debug=False, 
                      divide_by_baseline=True):
    errors = list()
    if (pred_importances1[-1].sum() == 0) and (pred_importances2[-1].sum() == 0):
            errors.append(0)
    elif (pred_importances1[-1].sum() == 0) or (pred_importances2[-1].sum() == 0):
        if not ignore_mismatch:
            if divide_by_baseline:
                baseline = baseline_error(pred_importances1[-1])
                if baseline == 0:
                    errors.append(1)
                errors.append(mean_absolute_error(pred_importances1[-1, :], pred_importances2[-1, :]) / baseline_error(pred_importances1[-1]))
            else:
                errors.append(mean_absolute_error(pred_importances1[-1, :], pred_importances2[-1, :]))
    else:
        if divide_by_baseline:
            baseline = baseline_error(pred_importances1[-1])
            if baseline == 0:
                errors.append(1)
            else:
                error = mean_absolute_error(pred_importances1[-1, :], pred_importances2[-1, :]) / baseline_error(pred_importances1[-1])
                errors.append(error)
        else:
            errors.append(mean_absolute_error(pred_importances1[-1, :], pred_importances2[-1, :]))
    
    #print(errors)
    pred_importances1 = pred_importances1[:-1]
    pred_importances2 = pred_importances2[:-1]
    if (len(pred_importances1) == 0) and (len(pred_importances2) == 0):
        errors.append(0)
    else:
        if not ignore_mismatch:
            #  doesn't ignore if there is a different number of not-contained subsequences i.e. the surplus vectors will
            #  be matched with all 0's vectors
            mismatch = len(pred_importances1) - len(pred_importances2)
            if mismatch != 0:
                if mismatch > 0:
                    if len(pred_importances2) == 0:
                        pred_importances2 = np.zeros(shape=(abs(mismatch), pred_importances1.shape[1]))
                    else:
                        pred_importances2 = np.append(pred_importances2,
                                                      np.zeros(shape=(abs(mismatch), pred_importances1.shape[1])), axis=0)
                else:
                    if len(pred_importances1) == 0:
                        pred_importances1 = np.zeros(shape=(abs(mismatch), pred_importances1.shape[1]))
                    else:
                        pred_importances1 = np.append(pred_importances1,
                                                      np.zeros(shape=(abs(mismatch), pred_importances1.shape[1])), axis=0)
        else:
            if ((len(pred_importances1) == 0) or (len(pred_importances2) == 0)):
                return np.mean(errors)
        distance_matrix = cdist(pred_importances1, pred_importances2, metric=mean_absolute_error)
        #print(distance_matrix)
        if debug:
            print(distance_matrix)
        while (distance_matrix.shape[1] > 0) and (len(distance_matrix) > 0):
            if debug:
                print(distance_matrix)
            to_delete = np.unravel_index(np.argmin(distance_matrix), shape=distance_matrix.shape)
            if divide_by_baseline:
                baseline = baseline_error(pred_importances1[to_delete[0]])
                if baseline == 0:
                    errors.append(1)  # FIXME: limit case
                else:
                    errors.append(distance_matrix.min() / baseline)
            else:
                errors.append(distance_matrix.min())
            distance_matrix = np.delete(distance_matrix, to_delete[0], axis=0)
            distance_matrix = np.delete(distance_matrix, to_delete[1], axis=1)
    """ print("--")
    print(np.mean(errors))
    print("--")"""
    return np.mean(errors)

# %%
np.random.randint(0,10,size=(2,2)).min()
# Out:
# 2

# %%
"""def instability_lasts(pred_importances1, pred_importances2, ignore_mismatch=False, debug=False, 
                      divide_by_baseline=True):
    errors = list()
    if divide_by_baseline:
        baseline = baseline_error(pred_importances1[-1])
        if baseline == 0:
            if (pred_importances1[-1].sum() == 0) and (pred_importances2[-1].sum() == 0):
                errors.append(0)
            else:
                errors.append(1)
        else:
            errors.append(mean_absolute_error(pred_importances1[-1, :], pred_importances2[-1, :]) / baseline_error(
                pred_importances1[-1]))
    else:
        errors.append(mean_absolute_error(pred_importances1[-1, :], pred_importances2[-1, :]))

    if debug:
        print(mean_absolute_error(pred_importances1[-1, :], pred_importances2[-1, :]))

    pred_importances1 = pred_importances1[:-1]
    pred_importances2 = pred_importances2[:-1]
    if (len(pred_importances1) == 0) and (len(pred_importances2) == 0):
        errors.append(0)
    else:
        if not ignore_mismatch:
            #  doesn't ignore if there is a different number of not-contained subsequences i.e. the surplus vectors will
            #  be matched with all 0's vectors
            mismatch = len(pred_importances1) - len(pred_importances2)
            if mismatch != 0:
                if mismatch > 0:
                    if len(pred_importances2) == 0:
                        pred_importances2 = np.zeros(shape=(abs(mismatch), pred_importances1.shape[1]))
                    else:
                        pred_importances2 = np.append(pred_importances2,
                                                      np.zeros(shape=(abs(mismatch), pred_importances1.shape[1])), axis=0)
                else:
                    if len(pred_importances1) == 0:
                        pred_importances1 = np.zeros(shape=(abs(mismatch), pred_importances1.shape[1]))
                    else:
                        pred_importances1 = np.append(pred_importances1,
                                                      np.zeros(shape=(abs(mismatch), pred_importances1.shape[1])), axis=0)
        else:
            if ((len(pred_importances1) == 0) or (len(pred_importances2) == 0)):
                return np.mean(errors)
        distance_matrix = cdist(pred_importances1, pred_importances2, metric=mean_absolute_error)
        if debug:
            print(distance_matrix)
        while (distance_matrix.shape[1] > 0) and (len(distance_matrix) > 0):
            if debug:
                print(distance_matrix)
            to_delete = np.unravel_index(np.argmin(distance_matrix), shape=distance_matrix.shape)
            if divide_by_baseline:
                baseline = baseline_error(pred_importances1[to_delete[0]])
                if baseline == 0:
                    errors.append(1)  # FIXME: limit case
                else:
                    errors.append(distance_matrix.min() / baseline)
            else:
                errors.append(distance_matrix.min())
            distance_matrix = np.delete(distance_matrix, to_delete[0], axis=0)
            distance_matrix = np.delete(distance_matrix, to_delete[1], axis=1)
    return np.mean(errors)"""

# %%
stability_shap_nobase = load(parentdir + "/test_metrics/stab_temp/instabilities_manifest_shap_nobase.joblib")

# %%
stability_shap_nobase
# Out:
# {'cbf_knn':     cbf_knn_shap_nochange
#  0                0.686503
#  1                0.053981
#  2                0.225240
#  3                0.000000
#  4                0.050210
#  5                0.045573
#  6                0.908854
#  7                0.000000
#  8                0.650974
#  9                0.000000
#  10               0.407451
#  11               0.200047
#  12               0.000000
#  13               0.700521
#  14               0.444556
#  15               0.145833
#  16               0.143229
#  17               0.249972
#  18               0.050210
#  19               0.063244
#  20               0.039063
#  21               0.117188
#  22               0.436198
#  23               0.278172
#  24               0.249972
#  25               0.000000
#  26               0.278172
#  27               0.053981
#  28               0.478601
#  29               0.045573
#  30               0.000000
#  31               0.005580
#  32               0.638198
#  33               0.107840
#  34               0.145833
#  35               0.267519,
#  'cbf_resnet':     cbf_resnet_shap_nochange
#  0                   0.143202
#  1                   0.012136
#  2                   0.335720
#  3                   0.010324
#  4                   0.087981
#  5                   0.304982
#  6                   0.137916
#  7                   0.014765
#  8                   0.163013
#  9                   0.010324
#  10                  0.271131
#  11                  0.406324
#  12                  0.011626
#  13                  0.126942
#  14                  0.124559
#  15                  0.203368
#  16                  0.182150
#  17                  0.251538
#  18                  0.087981
#  19                  0.221787
#  20                  0.094357
#  21                  0.356447
#  22                  0.138874
#  23                  0.202252
#  24                  0.251538
#  25                  0.014765
#  26                  0.202252
#  27                  0.012136
#  28                  0.269503
#  29                  0.304982
#  30                  0.061347
#  31                  0.004822
#  32                  0.111794
#  33                  0.189600
#  34                  0.203368
#  35                  0.205408,
#  'coffee_knn':     coffee_knn_shap_nochange
#  0                   0.135586
#  1                   0.186481
#  2                   0.226261
#  3                   0.192106
#  4                   0.169806
#  5                   0.260190
#  6                   0.244979
#  7                   0.174230
#  8                   0.166869
#  9                   0.369988
#  10                  0.240776
#  11                  0.186037
#  12                  0.165227
#  13                  0.183252
#  14                  0.200057
#  15                  0.216955
#  16                  0.321036
#  17                  0.240862
#  18                  0.168061
#  19                  0.359974
#  20                  0.348566
#  21                  0.262662
#  22                  0.209980
#  23                  0.294053
#  24                  0.222113
#  25                  0.275088
#  26                  0.342009
#  27                  0.217282,
#  'coffee_resnet':     coffee_resnet_shap_nochange
#  0                      0.251484
#  1                      0.108318
#  2                      0.143856
#  3                      0.194389
#  4                      0.144633
#  5                      0.133871
#  6                      0.242335
#  7                      0.099431
#  8                      0.121222
#  9                      0.162960
#  10                     0.145923
#  11                     0.115714
#  12                     0.107112
#  13                     0.115349
#  14                     0.132631
#  15                     0.171094
#  16                     0.335627
#  17                     0.349015
#  18                     0.210091
#  19                     0.313223
#  20                     0.352893
#  21                     0.425980
#  22                     0.224190
#  23                     0.154990
#  24                     0.150237
#  25                     0.208750
#  26                     0.249489
#  27                     0.137796,
#  'ecg200_knn':     ecg200_knn_shap_nochange
#  0                   0.171618
#  1                   0.239175
#  2                   0.216086
#  3                   0.329763
#  4                   0.311656
#  ..                       ...
#  95                  0.137850
#  96                  0.251523
#  97                  0.133356
#  98                  0.232094
#  99                  0.475603
#
#  [100 rows x 1 columns],
#  'ecg200_resnet':     ecg200_resnet_shap_nochange
#  0                      0.439933
#  1                      0.208912
#  2                      0.365890
#  3                      0.634583
#  4                      0.433726
#  ..                          ...
#  95                     0.203636
#  96                     0.271396
#  97                     0.221622
#  98                     0.116569
#  99                     0.413680
#
#  [100 rows x 1 columns],
#  'gunpoint_knn':     gunpoint_knn_shap_nochange
#  0                     0.188722
#  1                     0.210000
#  2                     0.330886
#  3                     0.206654
#  4                     0.407139
#  5                     0.221588
#  6                     0.092735
#  7                     0.415556
#  8                     0.277080
#  9                     0.088590
#  10                    0.329037
#  11                    0.058448
#  12                    0.128620
#  13                    0.085233
#  14                    0.126967
#  15                    0.330886
#  16                    0.435466
#  17                    0.396522
#  18                    0.207027
#  19                    0.177888
#  20                    0.188722
#  21                    0.086498
#  22                    0.105323
#  23                    0.366374
#  24                    0.222684
#  25                    0.397841
#  26                    0.691111
#  27                    0.355763
#  28                    0.347136
#  29                    0.085233
#  30                    0.241035
#  31                    0.415556
#  32                    0.358515
#  33                    0.202821
#  34                    0.146158
#  35                    0.208550
#  36                    0.162226
#  37                    0.078059
#  38                    0.150828
#  39                    0.147204
#  40                    0.277080
#  41                    0.000000
#  42                    0.210000
#  43                    0.000000
#  44                    0.105323
#  45                    0.000000
#  46                    0.146158
#  47                    0.245565
#  48                    0.086996
#  49                    0.222684,
#  'gunpoint_resnet':     gunpoint_resnet_shap_nochange
#  0                        0.304178
#  1                        0.330045
#  2                        0.242758
#  3                        0.260468
#  4                        0.236453
#  5                        0.191977
#  6                        0.220804
#  7                        0.181710
#  8                        0.333877
#  9                        0.667468
#  10                       0.222556
#  11                       0.228196
#  12                       0.145149
#  13                       0.279095
#  14                       0.180504
#  15                       0.242758
#  16                       0.189769
#  17                       0.314821
#  18                       0.337085
#  19                       0.684994
#  20                       0.304178
#  21                       0.318134
#  22                       0.190489
#  23                       0.410008
#  24                       0.173384
#  25                       0.180728
#  26                       0.262129
#  27                       0.167863
#  28                       0.177040
#  29                       0.279095
#  30                       0.211534
#  31                       0.181710
#  32                       0.413463
#  33                       0.135066
#  34                       0.168045
#  35                       0.176686
#  36                       0.682656
#  37                       0.057933
#  38                       0.165294
#  39                       0.417259
#  40                       0.333877
#  41                       0.179299
#  42                       0.330045
#  43                       0.179299
#  44                       0.190489
#  45                       0.195361
#  46                       0.168045
#  47                       0.185177
#  48                       0.200432
#  49                       0.173384}

# %%
columns_ = list(stability_shap_nobase.keys())

# %%
for i in range(len(columns_)):
    columns_[i] = columns_[i] + "_shap"

# %%
df_ = list()
for key in stability_shap_nobase:
    df_.append(stability_shap_nobase[key].values.ravel())

# %%
df_=pd.DataFrame(df_).T

# %%
df_.columns=columns_

# %%
df_shap = df_

# %%
df_shap.to_csv("stabilities_shap_nobase_nochange.csv", sep=";", index=False)

# %%
df_["cbf_resnet_shap_nochange"]
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
#       ..
# 45   NaN
# 46   NaN
# 47   NaN
# 48   NaN
# 49   NaN
# Name: cbf_resnet_shap_nochange, Length: 428, dtype: float64
