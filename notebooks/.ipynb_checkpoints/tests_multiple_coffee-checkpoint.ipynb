# %%
import os,sys,inspect
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0,parentdir)

# %%
from blackbox_wrapper import BlackboxWrapper
import keras
from datasets import build_coffee
from variational_autoencoder import load_model
from neighborhood_generators import NeighborhoodGenerator
from lore_wrapper import LoreWrapper
from utils import choose_z
from joblib import load
from lasts import load_multiple_lasts
import time
import numpy as np
from tests_multiple_lasts import generate_neighborhoods, multiple_tests, multiple_surrogate_fitting
from sbgdt import Sbgdt, generate_n_shapelets_per_size
from saxdt import Saxdt

# %%
random_state = 0
np.random.seed(random_state)
dataset_name = "coffee"
blackbox_name = "resnet"

file_path = parentdir + "/saved/" + dataset_name + "_" + blackbox_name + "_" + time.strftime("%Y%m%d_%H%M%S")

(X_train, y_train, X_val, y_val,
 X_test, y_test, X_exp_train, y_exp_train,
 X_exp_val, y_exp_val, X_exp_test, y_exp_test) = build_coffee(
    random_state = random_state
)

knn = load(parentdir + "/trained_models/coffee/coffee_knn.joblib")
resnet = keras.models.load_model(parentdir + "/trained_models/coffee/coffee_resnet.h5")

_, _, autoencoder = load_model(parentdir + "/trained_models/coffee/coffee_vae")

blackbox = BlackboxWrapper(knn, 2, 1)
encoder = autoencoder.layers[2]
decoder = autoencoder.layers[3]
# Out:
# DATASET INFO:
# X SHAPE:  (28, 286, 1)
# y SHAPE:  (28,)
#
# CLASSES BALANCE
# 0 :  0.5
# 1 :  0.5
#
# SHAPES:
# BLACKBOX TRAINING SET:  (28, 286, 1)
# BLACKBOX VALIDATION SET:  (0,)
# BLACKBOX TEST SET:  (28, 286, 1)
# EXPLANATION TRAINING SET:  (28, 286, 1)
# EXPLANATION VALIDATION SET:  (0,)
# EXPLANATION TEST SET:  (28, 286, 1)
# WARNING:tensorflow:From /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# /Users/francesco/github/LASTS/datasets.py:521: UserWarning: The validation sets are empty, use cross-validation to evaluate models
#   warnings.warn("The validation sets are empty, use cross-validation to evaluate models")
# /Users/francesco/github/LASTS/datasets.py:522: UserWarning: Blackbox and Explanation sets are the same
#   warnings.warn("Blackbox and Explanation sets are the same")

# %%
neighborhood_names = ["gaussian_matched", "uniform_sphere", "gaussian", "matched_uniform"]
neighborhood_kwargs_list = [
        {
            "n": 500,
            "n_search": 10000,
            "threshold": 2,
            "kind": "gaussian_matched",
            "sampling_kind": "gaussian_matched",
            "verbose": False,
            "redo_search": True,
            "forced_balance_ratio": 0.5,
            "cut_radius": False
        },
        {
            "n": 500,
            "n_search": 10000,
            "threshold": 2,
            "kind": "uniform_sphere",
            "sampling_kind": "uniform_sphere",
            "verbose": False,
            "redo_search": True,
            "forced_balance_ratio": 0.5,
            "cut_radius": True
        },
        {
            "n": 500,
            "n_search": 10000,
            "threshold": 2,
            "kind": "gaussian",
            "sampling_kind": "gaussian",
            "verbose": False,
            "redo_search": True,
            "forced_balance_ratio": 0.5,
            "cut_radius": False
        },
        {
            "n": 500,
            "n_search": 10000,
            "threshold": 2,
            "kind": "gaussian_matched",
            "sampling_kind": "uniform_sphere",
            "verbose": False,
            "redo_search": True,
            "forced_balance_ratio": 0.5,
            "cut_radius": True
        },
    ]

# %%
n_shapelets_per_size = generate_n_shapelets_per_size(X_train.shape[1], n_shapelets_per_length=2, 
                                                     min_length=8, start_divider=2, divider_multiplier=1.35)
surrogate_kwargs_list = [{"shapelet_model_params": {"max_iter": 50, "n_shapelets_per_size":n_shapelets_per_size}, 
                          "random_state": random_state},
                             {"random_state": np.random.seed(0), "create_plotting_dictionaries":False}]

surrogate_list = [Sbgdt, Saxdt]
surrogate_names = ["stdt20", "saxdt"]

# %%
neighborhood_list = [LoreWrapper]
neighborhood_names = ["lore"]
neighborhood_kwargs_list = [{"verbose": False, "samples": 500, "ngen": 10}]
surrogate_kwargs_list = [{"shapelet_model_params": {"max_iter": 50}, "random_state": random_state}, 
                         {"random_state": np.random.seed(0), "create_plotting_dictionaries":False}]
surrogate_list = [Sbgdt, Saxdt]
surrogate_names = ["stdt", "saxdt"]

# %%
# %%time
out = multiple_tests(
        X_exp_test,
        blackbox,
        encoder,
        decoder,
        neighborhood_list=neighborhood_list
        neighborhood_kwargs_list=neighborhood_kwargs_list,
        neighborhood_names=neighborhood_names,
        surrogate_list=surrogate_list,
        surrogate_kwargs_list=surrogate_kwargs_list,
        surrogate_names=surrogate_names,
        file_path=file_path,
        random_state=random_state,
        n_instances_to_explain=1,
        verbose=True,
        simple_dump=[False, True],
        boxplots=True,
        labels=["Robusta", "Arabica"]
    )
# Out:
# Accuracy: 1.0 ± 0.0
# 1.0
#
#
# NEIGHBORHOOD GENERATIONS
#
#
#
#  1 / 100
#
# Binary sampling search:
#    Testing threshold value: 2.0
#    Testing threshold value: 1.0
#    Best threshold found: 2.0
#    Final counterfactual search... (this could take a while) Done!
# Setting new threshold at radius: 1.4059891007650334
#
# Sampling --> uniform_sphere
# Forced balancing neighborhood... Done!
#
# LABELS BALANCE
# 0 :  0.5
# 1 :  0.5
#
# BINARY BALANCE
# not-1 :  0.5
# 1 :  0.5
#
#
# SURROGATE FITTING
#
#
#
#  Surrogate sbgdt : 1 / 100
#
# WARNING:tensorflow:From /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/tensorflow/python/ops/math_grad.py:102: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
#
#  Surrogate saxdt : 1 / 100
# CPU times: user 21min 32s, sys: 9.9 s, total: 21min 42s
# Wall time: 7min 25s

# %%
lasts_list = load_multiple_lasts(
    file_path=parentdir + "/saved/ecg200_20201027_010633/gaussian_matched_saxdt", 
    load_sbgdt_model=True,
    locator=False,
    model=False,
    verbose=True,
    simple_load=True
)
# Out:
# WARNING:tensorflow:From /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/keras/engine/saving.py:310: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '

# %%
read_metrics_csv(parentdir + "/test_metrics/ecg200/", figsize=(15,5))
# Out:
# gaussian_matched_saxdt fidelity_x: 0.96
# gaussian_matched_sbgdt fidelity_x: 0.91
# gaussian_saxdt fidelity_x: 0.99
# gaussian_sbgdt fidelity_x: 0.91
# uniform_sphere_saxdt fidelity_x: 0.99
# uniform_sphere_sbgdt fidelity_x: 0.93
# [    fidelity_neighborhood  fidelity_x  factual_coverage  \
#  0                   0.972         1.0             0.292
#  1                   0.996         1.0             0.470
#  2                   0.994         1.0             0.392
#  3                   0.998         1.0             0.442
#  4                   0.984         1.0             0.396
#  ..                    ...         ...               ...
#  95                  0.996         1.0             0.008
#  96                  1.000         1.0             0.478
#  97                  0.958         1.0             0.468
#  98                  1.000         1.0             0.460
#  99                  0.968         1.0             0.314
#
#      counterfactual_coverage  factual_precision  counterfactual_precision  \
#  0                     0.052           1.000000                  0.923077
#  1                     0.006           0.995745                  0.666667
#  2                     0.002           1.000000                  1.000000
#  3                     0.006           1.000000                  1.000000
#  4                     0.010           0.994949                  0.800000
#  ..                      ...                ...                       ...
#  95                    0.478           1.000000                  0.995816
#  96                    0.002           1.000000                  1.000000
#  97                    0.020           0.965812                  1.000000
#  98                    0.476           1.000000                  1.000000
#  99                    0.012           1.000000                  0.500000
#
#      factual_length  counterfactual_length
#  0                1                      4
#  1                3                      3
#  2                4                      5
#  3                5                      6
#  4                1                      3
#  ..             ...                    ...
#  95               2                      4
#  96               3                      3
#  97               3                      3
#  98               1                      3
#  99               4                      6
#
#  [100 rows x 8 columns],
#      fidelity_neighborhood  fidelity_x  factual_coverage  \
#  0                   0.732         1.0             0.222
#  1                   0.828         0.0             0.556
#  2                   0.820         1.0             0.312
#  3                   0.900         1.0             0.388
#  4                   0.784         1.0             0.108
#  ..                    ...         ...               ...
#  95                  0.748         1.0             0.132
#  96                  0.772         1.0             0.296
#  97                  0.780         1.0             0.170
#  98                  0.894         1.0             0.390
#  99                  0.836         1.0             0.400
#
#      counterfactual_coverage  factual_precision  counterfactual_precision  \
#  0                     0.006           0.783784                  0.666667
#  1                     0.080           0.794964                  0.925000
#  2                     0.374           0.884615                  0.689840
#  3                     0.446           0.938144                  0.946188
#  4                     0.002           0.981481                  1.000000
#  ..                      ...                ...                       ...
#  95                    0.014           0.742424                  1.000000
#  96                    0.704           0.959459                  0.693182
#  97                    0.004           0.929412                  1.000000
#  98                    0.360           1.000000                  0.977778
#  99                    0.600           0.920000                  0.780000
#
#      factual_length  counterfactual_length
#  0                5                      5
#  1                2                      2
#  2                2                      3
#  3                2                      1
#  4                2                      3
#  ..             ...                    ...
#  95               3                      3
#  96               1                      1
#  97               2                      4
#  98               1                      2
#  99               1                      1
#
#  [100 rows x 8 columns],
#      fidelity_neighborhood  fidelity_x  factual_coverage  \
#  0                   0.962         1.0             0.280
#  1                   1.000         1.0             0.424
#  2                   0.944         1.0             0.484
#  3                   0.982         1.0             0.476
#  4                   0.992         1.0             0.332
#  ..                    ...         ...               ...
#  95                  1.000         1.0             0.460
#  96                  0.982         1.0             0.482
#  97                  0.972         1.0             0.382
#  98                  0.978         1.0             0.472
#  99                  0.988         1.0             0.448
#
#      counterfactual_coverage  factual_precision  counterfactual_precision  \
#  0                     0.004           1.000000                  0.500000
#  1                     0.002           1.000000                  1.000000
#  2                     0.062           0.942149                  0.741935
#  3                     0.010           0.995798                  0.600000
#  4                     0.002           0.993976                  1.000000
#  ..                      ...                ...                       ...
#  95                    0.002           1.000000                  1.000000
#  96                    0.010           0.987552                  0.800000
#  97                    0.012           1.000000                  0.833333
#  98                    0.486           0.995763                  0.991770
#  99                    0.002           0.986607                  1.000000
#
#      factual_length  counterfactual_length
#  0                5                      5
#  1                3                      3
#  2                2                      2
#  3                3                      3
#  4                4                      4
#  ..             ...                    ...
#  95               5                      5
#  96               2                      2
#  97               3                      3
#  98               1                      2
#  99               4                      4
#
#  [100 rows x 8 columns],
#      fidelity_neighborhood  fidelity_x  factual_coverage  \
#  0                   0.720         1.0             0.288
#  1                   0.778         0.0             0.542
#  2                   0.830         1.0             0.398
#  3                   0.918         1.0             0.462
#  4                   0.754         1.0             0.426
#  ..                    ...         ...               ...
#  95                  0.732         0.0             0.126
#  96                  0.722         1.0             0.094
#  97                  0.784         1.0             0.340
#  98                  0.836         0.0             0.528
#  99                  0.902         1.0             0.404
#
#      counterfactual_coverage  factual_precision  counterfactual_precision  \
#  0                     0.006           0.812500                  0.666667
#  1                     0.014           0.741697                  1.000000
#  2                     0.602           0.914573                  0.774086
#  3                     0.358           0.948052                  0.994413
#  4                     0.574           0.798122                  0.721254
#  ..                      ...                ...                       ...
#  95                    0.028           0.634921                  0.714286
#  96                    0.002           0.659574                  1.000000
#  97                    0.660           0.917647                  0.715152
#  98                    0.048           0.818182                  0.958333
#  99                    0.404           0.990099                  0.792079
#
#      factual_length  counterfactual_length
#  0                3                      3
#  1                3                      3
#  2                1                      1
#  3                1                      2
#  4                1                      1
#  ..             ...                    ...
#  95               2                      4
#  96               6                      6
#  97               1                      1
#  98               2                      2
#  99               1                      3
#
#  [100 rows x 8 columns],
#      fidelity_neighborhood  fidelity_x  factual_coverage  \
#  0                   0.998         1.0             0.324
#  1                   0.998         1.0             0.428
#  2                   0.992         1.0             0.398
#  3                   1.000         1.0             0.468
#  4                   0.994         1.0             0.300
#  ..                    ...         ...               ...
#  95                  1.000         1.0             0.428
#  96                  0.998         1.0             0.496
#  97                  1.000         1.0             0.430
#  98                  1.000         1.0             0.460
#  99                  0.976         1.0             0.400
#
#      counterfactual_coverage  factual_precision  counterfactual_precision  \
#  0                     0.004           1.000000                       1.0
#  1                     0.002           1.000000                       1.0
#  2                     0.002           1.000000                       1.0
#  3                     0.002           1.000000                       1.0
#  4                     0.002           1.000000                       1.0
#  ..                      ...                ...                       ...
#  95                    0.002           1.000000                       1.0
#  96                    0.002           0.995968                       1.0
#  97                    0.002           1.000000                       1.0
#  98                    0.486           1.000000                       1.0
#  99                    0.010           1.000000                       0.6
#
#      factual_length  counterfactual_length
#  0                4                      5
#  1                2                      2
#  2                5                      6
#  3                4                      4
#  4                3                      3
#  ..             ...                    ...
#  95               4                      5
#  96               4                      4
#  97               6                      7
#  98               1                      4
#  99               5                      6
#
#  [100 rows x 8 columns],
#      fidelity_neighborhood  fidelity_x  factual_coverage  \
#  0                   0.722         1.0             0.410
#  1                   0.846         1.0             0.478
#  2                   0.796         1.0             0.370
#  3                   0.944         1.0             0.458
#  4                   0.782         1.0             0.518
#  ..                    ...         ...               ...
#  95                  0.822         1.0             0.164
#  96                  0.782         1.0             0.414
#  97                  0.860         1.0             0.406
#  98                  0.852         0.0             0.468
#  99                  0.878         1.0             0.384
#
#      counterfactual_coverage  factual_precision  counterfactual_precision  \
#  0                     0.014           0.770732                  0.571429
#  1                     0.008           0.774059                  1.000000
#  2                     0.608           0.886486                  0.743421
#  3                     0.010           0.960699                  0.800000
#  4                     0.482           0.772201                  0.792531
#  ..                      ...                ...                       ...
#  95                    0.014           0.987805                  0.714286
#  96                    0.204           0.792271                  0.745098
#  97                    0.450           0.916256                  0.862222
#  98                    0.532           0.876068                  0.830827
#  99                    0.302           0.968750                  1.000000
#
#      factual_length  counterfactual_length
#  0                4                      4
#  1                2                      3
#  2                1                      2
#  3                2                      2
#  4                1                      1
#  ..             ...                    ...
#  95               3                      4
#  96               2                      3
#  97               1                      2
#  98               1                      1
#  99               1                      2
#
#  [100 rows x 8 columns]]

# %%
random_state = 0
np.random.seed(random_state)
dataset_name = "ecg200"
file_path = parentdir + "/saved/" + dataset_name + "_" + time.strftime("%Y%m%d_%H%M%S")

# %%
lasts_list = load_multiple_lasts(
    file_path=parentdir + "/saved/ecg200_20201027_010633/gaussian_matched_saxdt", 
    load_sbgdt_model=False,
    locator=False,
    model=False,
    verbose=True,
    simple_load=True
)
# Out:
# WARNING:tensorflow:From /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/keras/engine/saving.py:310: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '

# %%
lasts_list = load_multiple_lasts(
    file_path=parentdir + "/saved/ecg200_20201027_010633/gaussian_saxdt", 
    load_sbgdt_model=False,
    locator=False,
    model=False,
    verbose=True,
    simple_load=True
)

# %%
lasts_list = load_multiple_lasts(
    file_path=parentdir + "/saved/ecg200_20201027_010633/uniform_sphere_saxdt", 
    load_sbgdt_model=False,
    locator=False,
    model=False,
    verbose=True,
    simple_load=True
)

# %%
from sbgdt import generate_n_shapelets_per_size
n_shapelets_per_size=generate_n_shapelets_per_size(128, divider_multiplier=1.2)
print(n_shapelets_per_size)
surrogate_kwargs_list = [{"shapelet_model_params": {"max_iter": 50, "n_shapelets_per_size": n_shapelets_per_size}, 
                          "random_state": random_state}]
# Out:
# {64: 4, 53: 4, 44: 4, 37: 4, 30: 4, 25: 4, 21: 4, 17: 4, 14: 4, 12: 4, 10: 4, 8: 4}

# %%
out = multiple_surrogate_fitting(
        lasts_list,
        neighborhood_name="gaussian_matched",
        surrogate_list=[Sbgdt],
        surrogate_kwargs_list=surrogate_kwargs_list,
        surrogate_names=["sbgdt_plus"],
        file_path=file_path,
        verbose=True,
        simple_dump=[False]
)
# Out:
# SURROGATE FITTING
#
#
#
#  Surrogate sbgdt_plus : 1 / 100
#
# WARNING:tensorflow:From /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /Users/francesco/anaconda3/envs/lasts_01/lib/python3.6/site-packages/tensorflow/python/ops/math_grad.py:102: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
#
#  Surrogate sbgdt_plus : 2 / 100
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-1ddeab19c795> in <module>
#       7         file_path=file_path,
#       8         verbose=True,
# ----> 9         simple_dump=[False]
#      10 )
#
# ~/github/LASTS/tests_multiple_lasts.py in multiple_surrogate_fitting(lasts_list, neighborhood_name, surrogate_list, surrogate_kwargs_list, surrogate_names, file_path, verbose, simple_dump, **kwargs)
#     133                 print("\n", "Surrogate", surrogate_names[j], ":", i + 1, "/", len(lasts_list), "\n")
#     134             surrogate = surrogate_(**surrogate_kwargs_list[j])
# --> 135             lasts_.fit_surrogate(surrogate, binarize_labels=True)
#     136             metrics = dump_metrics(lasts_)
#     137             metrics_dict[combination_names[j]] = pd.concat([metrics_dict[combination_names[j]],
#
# ~/github/LASTS/lasts.py in fit_surrogate(self, surrogate, binarize_labels, **kwargs)
#     815             ]
#     816             # self.surrogate.fit(self.Z_tilde[:, :, 0], 1 * (self.y == self.x_label))
# --> 817             self.surrogate.fit(self.Z_tilde, 1 * (self.y == self.x_label))
#     818         return self.surrogate
#     819
#
# ~/github/LASTS/sbgdt.py in fit(self, X, y)
#     624                                 verbose=self.shapelet_model_params.get("verbose", 0))
#     625
# --> 626         shp_clf.fit(X, y)
#     627         X_transformed = shp_clf.transform(X)
#     628         self.X_transformed = X_transformed
#
# ~/anaconda3/envs/lasts_01/lib/python3.6/site-packages/tslearn/shapelets.py in fit(self, X, y)
#     422             self.n_shapelets_per_size_ = self.n_shapelets_per_size
#     423
# --> 424         self._set_model_layers(X=X, ts_sz=sz, d=d, n_classes=n_classes)
#     425         self.transformer_model_.compile(loss="mean_squared_error",
#     426                                         optimizer=self.optimizer)
#
# ~/anaconda3/envs/lasts_01/lib/python3.6/site-packages/tslearn/shapelets.py in _set_model_layers(self, X, ts_sz, d, n_classes)
#     565                     self.n_shapelets_per_size_[sz], X=X,
#     566                     name="shapelets_%d_%d" % (i, di)
# --> 567                 )(transformer_layers[di]) for di in range(d)
#     568             ]
#     569
#
# ~/anaconda3/envs/lasts_01/lib/python3.6/site-packages/tslearn/shapelets.py in <listcomp>(.0)
#     565                     self.n_shapelets_per_size_[sz], X=X,
#     566                     name="shapelets_%d_%d" % (i, di)
# --> 567                 )(transformer_layers[di]) for di in range(d)
#     568             ]
#     569
#
# ~/anaconda3/envs/lasts_01/lib/python3.6/site-packages/keras/engine/base_layer.py in __call__(self, inputs, **kwargs)
#     423                                          'You can build it manually via: '
#     424                                          '`layer.build(batch_input_shape)`')
# --> 425                 self.build(unpack_singleton(input_shapes))
#     426                 self.built = True
#     427
#
# ~/anaconda3/envs/lasts_01/lib/python3.6/site-packages/tslearn/shapelets.py in build(self, input_shape)
#     126                                       shape=(self.n_shapelets, input_shape[2]),
#     127                                       initializer=self.initializer,
# --> 128                                       trainable=True)
#     129         super(LocalSquaredDistanceLayer, self).build(input_shape)
#     130
#
# ~/anaconda3/envs/lasts_01/lib/python3.6/site-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# ~/anaconda3/envs/lasts_01/lib/python3.6/site-packages/keras/engine/base_layer.py in add_weight(self, name, shape, dtype, initializer, regularizer, trainable, constraint)
#     241         if dtype is None:
#     242             dtype = self.dtype
# --> 243         weight = K.variable(initializer(shape, dtype=dtype),
#     244                             dtype=dtype,
#     245                             name=name,
#
# ~/anaconda3/envs/lasts_01/lib/python3.6/site-packages/tslearn/shapelets.py in __call__(self, shape, dtype)
#      96         shapelets = _kmeans_init_shapelets(self.X_,
#      97                                            n_shapelets,
# ---> 98                                            shp_len)[:, :, 0]
#      99         return K.tensorflow_backend._to_tensor(x=shapelets, dtype=K.floatx())
#     100
#
# ~/anaconda3/envs/lasts_01/lib/python3.6/site-packages/tslearn/shapelets.py in _kmeans_init_shapelets(X, n_shapelets, shp_len, n_draw)
#      79     return TimeSeriesKMeans(n_clusters=n_shapelets,
#      80                             metric="euclidean",
# ---> 81                             verbose=False).fit(subseries).cluster_centers_
#      82
#      83
#
# ~/anaconda3/envs/lasts_01/lib/python3.6/site-packages/tslearn/clustering.py in fit(self, X, y)
#     785                     print("Init %d" % (n_successful + 1))
#     786                 n_attempts += 1
# --> 787                 self._fit_one_init(X_, x_squared_norms, rs)
#     788                 if self.inertia_ < min_inertia:
#     789                     best_correct_centroids = self.cluster_centers_.copy()
#
# ~/anaconda3/envs/lasts_01/lib/python3.6/site-packages/tslearn/clustering.py in _fit_one_init(self, X, x_squared_norms, rs)
#     672             if self.verbose:
#     673                 print("%.3f" % self.inertia_, end=" --> ")
# --> 674             self._update_centroids(X)
#     675
#     676             if numpy.abs(old_inertia - self.inertia_) < self.tol:
#
# ~/anaconda3/envs/lasts_01/lib/python3.6/site-packages/tslearn/clustering.py in _update_centroids(self, X)
#     743             else:
#     744                 self.cluster_centers_[k] = euclidean_barycenter(
# --> 745                     X=X[self.labels_ == k])
#     746
#     747     def fit(self, X, y=None):
#
# ~/anaconda3/envs/lasts_01/lib/python3.6/site-packages/tslearn/barycenters.py in euclidean_barycenter(X, weights)
#      63            [4.5]])
#      64     """
# ---> 65     X_ = to_time_series_dataset(X)
#      66     weights = _set_weights(weights, X_.shape[0])
#      67     return numpy.average(X_, axis=0, weights=weights)
#
# ~/anaconda3/envs/lasts_01/lib/python3.6/site-packages/tslearn/utils.py in to_time_series_dataset(dataset, dtype)
#     188         dataset = [dataset]
#     189     n_ts = len(dataset)
# --> 190     max_sz = max([ts_size(to_time_series(ts)) for ts in dataset])
#     191     d = to_time_series(dataset[0]).shape[1]
#     192     dataset_out = numpy.zeros((n_ts, max_sz, d), dtype=dtype) + numpy.nan
#
# ~/anaconda3/envs/lasts_01/lib/python3.6/site-packages/tslearn/utils.py in <listcomp>(.0)
#     188         dataset = [dataset]
#     189     n_ts = len(dataset)
# --> 190     max_sz = max([ts_size(to_time_series(ts)) for ts in dataset])
#     191     d = to_time_series(dataset[0]).shape[1]
#     192     dataset_out = numpy.zeros((n_ts, max_sz, d), dtype=dtype) + numpy.nan
#
# KeyboardInterrupt:
