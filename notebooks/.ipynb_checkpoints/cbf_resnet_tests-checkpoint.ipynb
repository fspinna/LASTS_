# %%
import os,sys,inspect
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0,parentdir)

# %%
from joblib import load
from blackbox_wrapper import BlackboxWrapper
import keras
from datasets import build_cbf
import time
from tests import build_multiple_lore_lasts
from lasts import load_multiple_lasts
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.
# /Users/francesco/anaconda3/envs/tesi/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Users/francesco/anaconda3/envs/tesi/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /Users/francesco/anaconda3/envs/tesi/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /Users/francesco/anaconda3/envs/tesi/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /Users/francesco/anaconda3/envs/tesi/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /Users/francesco/anaconda3/envs/tesi/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /Users/francesco/anaconda3/envs/tesi/lib/python3.6/site-packages/deap/tools/_hypervolume/pyhv.py:33: ImportWarning: Falling back to the python version of hypervolume module. Expect this to be very slow.
#   "module. Expect this to be very slow.", ImportWarning)

# %%
dataset_name = "cbf"
blackbox_name = "resnet"
file_path = parentdir + "/saved/" + dataset_name + "_" + blackbox_name + "_" + time.strftime("%Y%m%d_%H%M%S")

# %%
random_state = 0
(X_train, y_train, X_val, y_val, 
 X_test, y_test, X_exp_train, y_exp_train, 
 X_exp_val, y_exp_val, X_exp_test, y_exp_test) = build_cbf(n_samples = 600, 
                                             random_state = random_state)
# Out:
# DATASET INFO:
# X SHAPE:  (600, 128, 1)
# y SHAPE:  (600,)
#
# CLASSES BALANCE
# 0 :  0.33
# 1 :  0.33
# 2 :  0.33
#
# SHAPES:
# BLACKBOX TRAINING SET:  (268, 128, 1)
# BLACKBOX VALIDATION SET:  (68, 128, 1)
# BLACKBOX TEST SET:  (84, 128, 1)
# EXPLANATION TRAINING SET:  (115, 128, 1)
# EXPLANATION VALIDATION SET:  (29, 128, 1)
# EXPLANATION TEST SET:  (36, 128, 1)

# %%
resnet = keras.models.load_model(parentdir + "/trained_models/cbf/cbf_resnet.h5")
autoencoder = keras.models.load_model(parentdir + "/trained_models/cbf/cbf_ae.h5")

blackbox = BlackboxWrapper(resnet, 3, 2)
encoder = autoencoder.layers[1]
decoder = autoencoder.layers[2]
# Out:
# WARNING:tensorflow:From /Users/francesco/anaconda3/envs/tesi/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
generator_params = {"verbose":True, 
                    "ngen":5, 
                    "size":500, 
                    "samples": 500}
shapelet_model_params = {"max_iter":50}

# %%
# %%time
lasts_list = build_multiple_lore_lasts(
    blackbox,
    encoder,
    decoder,
    X_exp_test,
    file_path,
    generator_params = generator_params,
    shapelet_model_params = shapelet_model_params,
    verbose = True,
    n_instances_to_explain = None
    )
# Out:
# calculating feature values
# gen	nevals	avg     	min     	max
# 0  	250   	0.496654	0.496654	0.496654
# 1  	220   	0.534715	0.00669352	0.993307
# 2  	205   	0.65243 	0.00681955	0.993307
# 3  	212   	0.721082	0.00669397	0.993307
# 4  	209   	0.822192	0.00692204	0.993307
# 5  	207   	0.819796	0.00669919	0.993307
# gen	nevals	avg	min	max
# 0  	250   	0.5	0.5	0.5
# 1  	214   	0.551726	0.488589	0.992962
# 2  	219   	0.655225	0.485241	0.992878
# 3  	223   	0.767461	0.471584	0.993097
# 4  	205   	0.841267	0.471542	0.993097
# 5  	210   	0.879233	0.490292	0.993097
# synthetic neighborhood class counts {0: 230, 1: 235, 2: 85}
# WARNING:tensorflow:From /Users/francesco/anaconda3/envs/tesi/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /Users/francesco/anaconda3/envs/tesi/lib/python3.6/site-packages/tensorflow/python/ops/math_grad.py:102: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# learning local decision tree
# retrieving explanation
# 1 / 36
# calculating feature values
# gen	nevals	avg     	min     	max
# 0  	250   	0.496654	0.496654	0.496654
# 1  	212   	0.51989 	0.00669885	0.993204
# 2  	219   	0.624547	0.00669745	0.993307
# 3  	229   	0.734952	0.00673484	0.993307
# 4  	221   	0.752181	0.00669397	0.993307
# 5  	219   	0.797373	0.00671768	0.993307
# gen	nevals	avg	min	max
# 0  	250   	0.5	0.5	0.5
# 1  	224   	0.539463	0.0388378	0.99236
# 2  	213   	0.618722	0.00750492	0.993237
# 3  	217   	0.728969	0.0244871 	0.993297
# 4  	223   	0.802662	0.0115334 	0.993306
# 5  	208   	0.870408	0.0283289 	0.993306
# synthetic neighborhood class counts {0: 236, 1: 181, 2: 133}
# learning local decision tree
# retrieving explanation
# 2 / 36
# calculating feature values
# gen	nevals	avg     	min     	max
# 0  	250   	0.496654	0.496654	0.496654
# 1  	217   	0.538084	0.0066998	0.993307
# 2  	211   	0.619286	0.00669672	0.993307
# 3  	214   	0.791911	0.00694723	0.993307
# 4  	213   	0.809175	0.00669397	0.993307
# 5  	216   	0.832228	0.00669698	0.993307
# gen	nevals	avg	min	max
# 0  	250   	0.5	0.5	0.5
# 1  	205   	0.553295	0.482932	0.993254
# 2  	199   	0.63333 	0.472789	0.993254
# 3  	214   	0.692817	0.487302	0.993255
# 4  	221   	0.738837	0.48836 	0.993255
# 5  	213   	0.846842	0.484473	0.993257
# synthetic neighborhood class counts {0: 193, 1: 258, 2: 99}
# learning local decision tree
# retrieving explanation
# 3 / 36
# calculating feature values
# gen	nevals	avg     	min     	max
# 0  	250   	0.496654	0.496654	0.496654
# 1  	215   	0.505014	0.00669447	0.993194
# 2  	224   	0.59622 	0.00672779	0.993194
# 3  	206   	0.765429	0.0066947 	0.993304
# 4  	219   	0.805835	0.00670671	0.993307
# 5  	212   	0.798415	0.00678887	0.993307
# gen	nevals	avg	min	max
# 0  	250   	0.5	0.5	0.5
# 1  	213   	0.538987	0.0088135	0.993183
# 2  	214   	0.625186	0.0190029	0.993303
# 3  	217   	0.72366 	0.0344431	0.993303
# 4  	205   	0.816478	0.0245065	0.993303
# 5  	217   	0.87732 	0.00793219	0.993307
# synthetic neighborhood class counts {0: 230, 1: 162, 2: 158}
# learning local decision tree
# retrieving explanation
# 4 / 36
# calculating feature values
# gen	nevals	avg     	min     	max
# 0  	250   	0.496654	0.496654	0.496654
# 1  	215   	0.545462	0.00670058	0.993307
# 2  	201   	0.647955	0.00669346	0.993307
# 3  	210   	0.753349	0.00672201	0.993307
# 4  	211   	0.797903	0.00670248	0.993307
# 5  	205   	0.797297	0.00669374	0.993307
# gen	nevals	avg	min	max
# 0  	250   	0.5	0.5	0.5
# 1  	211   	0.568594	0.479777	0.993169
# 2  	212   	0.633569	0.490259	0.993148
# 3  	213   	0.736633	0.492071	0.993183
# 4  	209   	0.826465	0.483784	0.993188
# 5  	211   	0.831986	0.484392	0.993188
# synthetic neighborhood class counts {0: 215, 1: 244, 2: 91}
# learning local decision tree
# retrieving explanation
# 5 / 36
# calculating feature values
# gen	nevals	avg     	min     	max
# 0  	250   	0.496654	0.496654	0.496654
# 1  	209   	0.511654	0.00669311	0.993304
# 2  	221   	0.657704	0.0066932 	0.993306
# 3  	220   	0.754607	0.00669433	0.993307
# 4  	211   	0.836392	0.00670253	0.993307
# 5  	206   	0.865203	0.0067118 	0.993307
# gen	nevals	avg	min	max
# 0  	250   	0.5	0.5	0.5
# 1  	216   	0.483695	0.0189435	0.916821
# 2  	201   	0.485311	0.0140522	0.916821
# 3  	213   	0.494742	0.0163196	0.951714
# 4  	220   	0.488595	0.00799365	0.937349
# 5  	217   	0.513421	0.0167282 	0.981971
# synthetic neighborhood class counts {0: 158, 1: 98, 2: 294}
# learning local decision tree
# retrieving explanation
# 6 / 36
# calculating feature values
# gen	nevals	avg     	min     	max
# 0  	250   	0.496654	0.496654	0.496654
# 1  	210   	0.5537  	0.00670608	0.993306
# 2  	211   	0.732149	0.00669761	0.993307
# 3  	220   	0.865852	0.00674498	0.993306
# 4  	209   	0.89896 	0.00669526	0.993307
# 5  	208   	0.855493	0.006693  	0.993307
# gen	nevals	avg	min	max
# 0  	250   	0.5	0.5	0.5
# 1  	219   	0.481832	0.00727086	0.963573
# 2  	216   	0.495284	0.0147746 	0.963573
# 3  	204   	0.48828 	0.0112994 	0.965954
# 4  	218   	0.491062	0.00885703	0.986667
# 5  	217   	0.511991	0.0221818 	0.986667
# synthetic neighborhood class counts {0: 107, 1: 149, 2: 294}
# learning local decision tree
# retrieving explanation
# 7 / 36
# calculating feature values
# gen	nevals	avg     	min     	max
# 0  	250   	0.496654	0.496654	0.496654
# 1  	209   	0.515357	0.00671053	0.993307
# 2  	202   	0.610192	0.00670164	0.993307
# 3  	209   	0.683654	0.00669407	0.993307
# 4  	211   	0.734982	0.00675282	0.993307
# 5  	208   	0.774615	0.00669307	0.993307
# gen	nevals	avg	min	max
# 0  	250   	0.5	0.5	0.5
# 1  	216   	0.52937	0.0072147	0.992728
# 2  	205   	0.622839	0.00682273	0.993168
# 3  	214   	0.725553	0.00874721	0.9933
# 4  	206   	0.805853	0.04761   	0.993303
# 5  	211   	0.867994	0.112364  	0.993307
# synthetic neighborhood class counts {0: 229, 1: 163, 2: 158}
# learning local decision tree
# retrieving explanation
# 8 / 36
# calculating feature values
# gen	nevals	avg     	min     	max
# 0  	250   	0.496654	0.496654	0.496654
# 1  	204   	0.524429	0.00669459	0.993302
# 2  	206   	0.624153	0.00669448	0.993306
# 3  	217   	0.748903	0.00674991	0.993306
# 4  	212   	0.829088	0.00669429	0.993306
# 5  	222   	0.814114	0.0067382 	0.993306
# gen	nevals	avg	min	max
# 0  	250   	0.5	0.5	0.5
# 1  	211   	0.553962	0.492939	0.993229
# 2  	211   	0.641034	0.481344	0.992781
# 3  	203   	0.745496	0.484366	0.993235
# 4  	218   	0.817479	0.47602 	0.993239
# 5  	206   	0.858142	0.488459	0.99324
# synthetic neighborhood class counts {0: 215, 1: 246, 2: 89}
# learning local decision tree
# retrieving explanation
# 9 / 36
# calculating feature values
# gen	nevals	avg     	min     	max
# 0  	250   	0.496654	0.496654	0.496654
# 1  	209   	0.509093	0.00677134	0.993278
# 2  	208   	0.607676	0.00680398	0.993285
# 3  	212   	0.719019	0.00684711	0.993306
# 4  	206   	0.79384 	0.00675145	0.993306
# 5  	208   	0.819129	0.00690687	0.993306
# gen	nevals	avg	min	max
# 0  	250   	0.5	0.5	0.5
# 1  	217   	0.52998	0.00718156	0.986442
# 2  	215   	0.626072	0.0103528 	0.993306
# 3  	210   	0.720052	0.0166121 	0.993306
# 4  	220   	0.811052	0.00723604	0.993306
# 5  	219   	0.860578	0.0195957 	0.993307
# synthetic neighborhood class counts {0: 234, 1: 155, 2: 161}
# learning local decision tree
# retrieving explanation
# 10 / 36
# calculating feature values
# gen	nevals	avg     	min     	max
# 0  	250   	0.496654	0.496654	0.496654
# 1  	220   	0.53109 	0.00669354	0.993306
# 2  	213   	0.707747	0.0067475 	0.993307
# 3  	214   	0.780284	0.00675326	0.993307
# 4  	214   	0.845091	0.00670373	0.993307
# 5  	215   	0.84009 	0.00669516	0.993307
# gen	nevals	avg	min	max
# 0  	250   	0.5	0.5	0.5
# 1  	206   	0.482613	0.0269585	0.99067
# 2  	219   	0.480844	0.0143132	0.683696
# 3  	206   	0.490573	0.0268752	0.909667
# 4  	220   	0.485228	0.0102345	0.949562
# 5  	211   	0.536142	0.0228869	0.980266
# synthetic neighborhood class counts {0: 141, 1: 120, 2: 289}
# learning local decision tree
# retrieving explanation
# 11 / 36
# calculating feature values
# gen	nevals	avg     	min     	max
# 0  	250   	0.496654	0.496654	0.496654
# 1  	201   	0.539135	0.00671913	0.993303
# 2  	225   	0.678578	0.0067035 	0.993303
# 3  	217   	0.80255 	0.00674103	0.993307
# 4  	203   	0.840996	0.0067037 	0.993307
# 5  	218   	0.845515	0.00669541	0.993307
# gen	nevals	avg	min	max
# 0  	250   	0.5	0.5	0.5
# 1  	212   	0.475191	0.0122919	0.879957
# 2  	209   	0.489936	0.0592198	0.879957
# 3  	217   	0.490388	0.0220167	0.8184
# 4  	218   	0.493697	0.0131204	0.879957
# 5  	212   	0.525374	0.00904611	0.95825
# synthetic neighborhood class counts {0: 162, 1: 103, 2: 285}
# learning local decision tree
# retrieving explanation
# 12 / 36
# calculating feature values
# gen	nevals	avg     	min     	max
# 0  	250   	0.496654	0.496654	0.496654
# 1  	220   	0.494172	0.00686286	0.992689
# 2  	212   	0.591455	0.00675505	0.993306
# 3  	217   	0.699226	0.00708919	0.993307
# 4  	201   	0.772477	0.00697671	0.993307
# 5  	215   	0.788516	0.00713627	0.993307
# gen	nevals	avg	min	max
# 0  	250   	0.5	0.5	0.5
# 1  	220   	0.533757	0.00768395	0.993307
# 2  	223   	0.606479	0.00670639	0.993307
# 3  	207   	0.742332	0.00670639	0.993307
# 4  	214   	0.804963	0.0912068 	0.993307
# 5  	210   	0.828484	0.0777854 	0.993307
# synthetic neighborhood class counts {0: 240, 1: 116, 2: 194}
# learning local decision tree
# retrieving explanation
# 13 / 36
# calculating feature values
# gen	nevals	avg     	min     	max
# 0  	250   	0.496654	0.496654	0.496654
# 1  	212   	0.566409	0.0066959	0.993307
# 2  	209   	0.732522	0.00669416	0.993307
# 3  	220   	0.831551	0.00670682	0.993307
# 4  	221   	0.831556	0.00669987	0.993307
# 5  	208   	0.87572 	0.00670346	0.993307
# gen	nevals	avg	min	max
# 0  	250   	0.5	0.5	0.5
# 1  	216   	0.48192	0.0159974	0.648786
# 2  	227   	0.490102	0.0190239	0.77054
# 3  	216   	0.493236	0.008769 	0.99083
# 4  	210   	0.509576	0.00834179	0.99083
# 5  	207   	0.548304	0.0204221 	0.992632
# synthetic neighborhood class counts {0: 163, 1: 96, 2: 291}
# learning local decision tree
# retrieving explanation
# 14 / 36
# calculating feature values
# gen	nevals	avg     	min     	max
# 0  	250   	0.496654	0.496654	0.496654
# 1  	211   	0.533708	0.00675261	0.993306
# 2  	215   	0.643505	0.0066962 	0.993306
# 3  	212   	0.755425	0.00672037	0.993306
# 4  	201   	0.803885	0.00669403	0.993306
# 5  	207   	0.820334	0.00669367	0.993306
# gen	nevals	avg	min	max
# 0  	250   	0.5	0.5	0.5
# 1  	206   	0.581809	0.458399	0.992981
# 2  	209   	0.69615 	0.481951	0.992945
# 3  	212   	0.782482	0.467555	0.993015
# 4  	207   	0.842274	0.450788	0.993022
# 5  	200   	0.875613	0.459102	0.993012
# synthetic neighborhood class counts {0: 216, 1: 242, 2: 92}
# learning local decision tree
# retrieving explanation
# 15 / 36
# calculating feature values
# gen	nevals	avg     	min     	max
# 0  	250   	0.496654	0.496654	0.496654
# 1  	222   	0.477841	0.00669384	0.993307
# 2  	216   	0.673251	0.00674404	0.993307
# 3  	212   	0.755157	0.00669654	0.993307
# 4  	214   	0.801344	0.00669834	0.993307
# 5  	208   	0.810573	0.00674194	0.993307
# gen	nevals	avg	min	max
# 0  	250   	0.5	0.5	0.5
# 1  	222   	0.545859	0.172096	0.993306
# 2  	214   	0.66119 	0.0756795	0.993306
# 3  	214   	0.771046	0.0746362	0.993306
# 4  	210   	0.844203	0.488865 	0.993306
# 5  	207   	0.884117	0.0095358	0.993306
# synthetic neighborhood class counts {0: 237, 1: 185, 2: 128}
# learning local decision tree
# retrieving explanation
# 16 / 36
# calculating feature values
# gen	nevals	avg     	min     	max
# 0  	250   	0.496654	0.496654	0.496654
# 1  	217   	0.546834	0.00669549	0.993307
# 2  	229   	0.700153	0.00675403	0.993307
# 3  	205   	0.810013	0.00669545	0.993307
# 4  	207   	0.834276	0.006705  	0.993307
# 5  	210   	0.823758	0.00669407	0.993307
# gen	nevals	avg	min	max
# 0  	250   	0.5	0.5	0.5
# 1  	207   	0.481822	0.0154841	0.950721
# 2  	210   	0.485126	0.00785656	0.950721
# 3  	205   	0.500444	0.0244331 	0.951448
# 4  	217   	0.493917	0.00674879	0.951448
# 5  	214   	0.519541	0.00742178	0.986471
# synthetic neighborhood class counts {0: 174, 1: 89, 2: 271}
# learning local decision tree
# retrieving explanation
# 17 / 36
# calculating feature values
# gen	nevals	avg     	min     	max
# 0  	250   	0.496654	0.496654	0.496654
# 1  	200   	0.547815	0.00670243	0.993307
# 2  	208   	0.723646	0.00669487	0.993307
# 3  	218   	0.779443	0.00670555	0.993307
# 4  	211   	0.857632	0.00670029	0.993307
# 5  	223   	0.871284	0.00669586	0.993307
# gen	nevals	avg	min	max
# 0  	250   	0.5	0.5	0.5
# 1  	215   	0.488394	0.0401459	0.937389
# 2  	214   	0.471383	0.0116808	0.937389
# 3  	220   	0.472768	0.0332347	0.937389
# 4  	227   	0.474468	0.00908496	0.99156
# 5  	212   	0.512408	0.0131721 	0.99156
# synthetic neighborhood class counts {0: 151, 1: 86, 2: 313}
# learning local decision tree
# retrieving explanation
# 18 / 36
# calculating feature values
# gen	nevals	avg     	min     	max
# 0  	250   	0.496654	0.496654	0.496654
# 1  	221   	0.505063	0.00670233	0.993298
# 2  	213   	0.630997	0.00670191	0.993303
# 3  	203   	0.732336	0.00669594	0.993303
# 4  	206   	0.76608 	0.00669353	0.993299
# 5  	221   	0.800566	0.00669443	0.993306
# gen	nevals	avg	min	max
# 0  	250   	0.5	0.5	0.5
# 1  	221   	0.58647	0.486882	0.993133
# 2  	212   	0.66229	0.486947	0.993244
# 3  	217   	0.792925	0.494085	0.993244
# 4  	220   	0.849744	0.494309	0.993248
# 5  	211   	0.850959	0.486069	0.993248
# synthetic neighborhood class counts {0: 214, 1: 245, 2: 91}
# learning local decision tree
# retrieving explanation
# 19 / 36
# calculating feature values
# gen	nevals	avg     	min     	max
# 0  	250   	0.496654	0.496654	0.496654
# 1  	214   	0.465195	0.00697518	0.993305
# 2  	215   	0.59219 	0.00670725	0.993305
# 3  	211   	0.690843	0.006725  	0.993307
# 4  	215   	0.756929	0.00670532	0.993307
# 5  	205   	0.777082	0.00669285	0.993307
# gen	nevals	avg	min	max
# 0  	250   	0.5	0.5	0.5
# 1  	207   	0.532334	0.0067858	0.993292
# 2  	220   	0.609559	0.00817213	0.992841
# 3  	210   	0.690296	0.00669312	0.993124
# 4  	229   	0.766677	0.00674387	0.993181
# 5  	210   	0.82088 	0.00672056	0.993181
# synthetic neighborhood class counts {0: 246, 1: 150, 2: 154}
# learning local decision tree
# retrieving explanation
# 20 / 36
# calculating feature values
# gen	nevals	avg     	min     	max
# 0  	250   	0.496654	0.496654	0.496654
# 1  	204   	0.546852	0.00671117	0.993307
# 2  	210   	0.717157	0.00669969	0.993307
# 3  	222   	0.815701	0.00670187	0.993307
# 4  	208   	0.85315 	0.00669346	0.993307
# 5  	219   	0.831887	0.00669878	0.993307
# gen	nevals	avg	min	max
# 0  	250   	0.5	0.5	0.5
# 1  	212   	0.482605	0.0103557	0.924259
# 2  	196   	0.492718	0.0110994	0.924259
# 3  	203   	0.505131	0.0102214	0.985308
# 4  	208   	0.526986	0.0127792	0.985511
# 5  	218   	0.564131	0.0117724	0.989243
# synthetic neighborhood class counts {0: 144, 1: 116, 2: 290}
# learning local decision tree
# retrieving explanation
# 21 / 36
# calculating feature values
# gen	nevals	avg     	min     	max
# 0  	250   	0.496654	0.496654	0.496654
# 1  	200   	0.561641	0.00670576	0.993307
# 2  	204   	0.678746	0.00676655	0.993307
# 3  	222   	0.798859	0.0066957 	0.993307
# 4  	201   	0.867676	0.00671057	0.993307
# 5  	226   	0.846357	0.00669318	0.993307
# gen	nevals	avg	min	max
# 0  	250   	0.5	0.5	0.5
# 1  	212   	0.479596	0.0307024	0.862465
# 2  	217   	0.471138	0.0118686	0.862465
# 3  	205   	0.487637	0.0107968	0.978057
# 4  	207   	0.508993	0.00881989	0.986877
# 5  	206   	0.531101	0.0102813 	0.986877
# synthetic neighborhood class counts {0: 187, 1: 63, 2: 300}
# learning local decision tree
# retrieving explanation
# 22 / 36
# calculating feature values
# gen	nevals	avg     	min     	max
# 0  	250   	0.496654	0.496654	0.496654
# 1  	215   	0.571316	0.0067046	0.993307
# 2  	204   	0.70732 	0.00669388	0.993307
# 3  	208   	0.83841 	0.00671377	0.993307
# 4  	209   	0.868349	0.00670604	0.993307
# 5  	205   	0.834211	0.00669967	0.993307
# gen	nevals	avg	min	max
# 0  	250   	0.5	0.5	0.5
# 1  	212   	0.488858	0.00930365	0.936259
# 2  	215   	0.500953	0.00930365	0.976141
# 3  	206   	0.514897	0.0117135 	0.976141
# 4  	207   	0.564091	0.00948194	0.984172
# 5  	223   	0.622011	0.0546965 	0.984172
# synthetic neighborhood class counts {0: 190, 1: 80, 2: 280}
# learning local decision tree
# retrieving explanation
# 23 / 36
# calculating feature values
# gen	nevals	avg     	min     	max
# 0  	250   	0.496654	0.496654	0.496654
# 1  	220   	0.51879 	0.00679959	0.993307
# 2  	209   	0.605979	0.00714731	0.993307
# 3  	216   	0.7196  	0.00669518	0.993307
# 4  	202   	0.798558	0.00671784	0.993307
# 5  	227   	0.827094	0.00681524	0.993307
# gen	nevals	avg	min	max
# 0  	250   	0.5	0.5	0.5
# 1  	224   	0.565527	0.462699	0.992745
# 2  	205   	0.672448	0.469732	0.992999
# 3  	216   	0.783001	0.474684	0.992999
# 4  	218   	0.855586	0.496315	0.992998
# 5  	211   	0.860271	0.452537	0.993
# synthetic neighborhood class counts {0: 201, 1: 243, 2: 106}
# learning local decision tree
# retrieving explanation
# 24 / 36
# calculating feature values
# gen	nevals	avg     	min     	max
# 0  	250   	0.496654	0.496654	0.496654
# 1  	199   	0.534238	0.00669408	0.993307
# 2  	201   	0.691144	0.00670204	0.993307
# 3  	209   	0.81212 	0.00669429	0.993307
# 4  	207   	0.869354	0.00670061	0.993307
# 5  	214   	0.849183	0.00669335	0.993307
# gen	nevals	avg	min	max
# 0  	250   	0.5	0.5	0.5
# 1  	204   	0.481395	0.00914417	0.770212
# 2  	224   	0.500943	0.100647  	0.925609
# 3  	213   	0.49536 	0.0116535 	0.925609
# 4  	210   	0.510794	0.0129219 	0.925609
# 5  	211   	0.527349	0.0144086 	0.944098
# synthetic neighborhood class counts {0: 149, 1: 111, 2: 290}
# learning local decision tree
# retrieving explanation
# 25 / 36
# calculating feature values
# gen	nevals	avg     	min     	max
# 0  	250   	0.496654	0.496654	0.496654
# 1  	220   	0.486554	0.0067717	0.992917
# 2  	213   	0.617068	0.00677349	0.993305
# 3  	203   	0.74864 	0.00690966	0.993239
# 4  	218   	0.775804	0.00672358	0.993307
# 5  	212   	0.799436	0.00674912	0.993307
# gen	nevals	avg	min	max
# 0  	250   	0.5	0.5	0.5
# 1  	214   	0.531288	0.00672447	0.992243
# 2  	223   	0.628412	0.0067135 	0.993239
# 3  	211   	0.73817 	0.00715466	0.993063
# 4  	210   	0.833442	0.00989111	0.993303
# 5  	206   	0.865363	0.136026  	0.993307
# synthetic neighborhood class counts {0: 242, 1: 125, 2: 183}
# learning local decision tree
# retrieving explanation
# 26 / 36
# calculating feature values
# gen	nevals	avg     	min     	max
# 0  	250   	0.496654	0.496654	0.496654
# 1  	212   	0.516393	0.00669555	0.993307
# 2  	214   	0.607397	0.00669439	0.993307
# 3  	218   	0.708045	0.00670392	0.993307
# 4  	204   	0.783552	0.00669818	0.993307
# 5  	209   	0.815778	0.00671204	0.993307
# gen	nevals	avg	min	max
# 0  	250   	0.5	0.5	0.5
# 1  	217   	0.558381	0.495095	0.992764
# 2  	210   	0.658377	0.450262	0.992765
# 3  	220   	0.770709	0.455269	0.992841
# 4  	217   	0.842178	0.466325	0.992842
# 5  	216   	0.88293 	0.488788	0.992842
# synthetic neighborhood class counts {0: 244, 1: 224, 2: 82}
# learning local decision tree
# retrieving explanation
# 27 / 36
# calculating feature values
# gen	nevals	avg     	min     	max
# 0  	250   	0.496654	0.496654	0.496654
# 1  	203   	0.532941	0.00669518	0.993303
# 2  	209   	0.620981	0.00676118	0.993305
# 3  	214   	0.702342	0.00669526	0.993304
# 4  	205   	0.813158	0.00669297	0.993307
# 5  	225   	0.787299	0.00671597	0.993307
# gen	nevals	avg	min	max
# 0  	250   	0.5	0.5	0.5
# 1  	218   	0.54613	0.0360442	0.993026
# 2  	215   	0.640529	0.00677602	0.99329
# 3  	216   	0.749148	0.0151099 	0.99329
# 4  	213   	0.833083	0.00819692	0.993307
# 5  	215   	0.837626	0.00935646	0.993307
# synthetic neighborhood class counts {0: 239, 1: 182, 2: 129}
# learning local decision tree
# retrieving explanation
# 28 / 36
# calculating feature values
# gen	nevals	avg     	min     	max
# 0  	250   	0.496654	0.496654	0.496654
# 1  	219   	0.524233	0.00670092	0.993307
# 2  	219   	0.63534 	0.00674936	0.993307
# 3  	220   	0.745733	0.00671607	0.993307
# 4  	216   	0.78113 	0.00672262	0.993307
# 5  	214   	0.847119	0.00669791	0.993307
# gen	nevals	avg	min	max
# 0  	250   	0.5	0.5	0.5
# 1  	204   	0.574132	0.486556	0.991018
# 2  	213   	0.682846	0.477681	0.991018
# 3  	210   	0.778605	0.477604	0.992599
# 4  	210   	0.84321 	0.463402	0.992829
# 5  	216   	0.856085	0.460673	0.992836
# synthetic neighborhood class counts {0: 226, 1: 242, 2: 82}
# learning local decision tree
# retrieving explanation
# 29 / 36
# calculating feature values
# gen	nevals	avg     	min     	max
# 0  	250   	0.496654	0.496654	0.496654
# 1  	208   	0.538617	0.00669486	0.993294
# 2  	209   	0.660674	0.00669383	0.993307
# 3  	217   	0.810043	0.0067983 	0.993307
# 4  	215   	0.851612	0.00669407	0.993307
# 5  	215   	0.866321	0.00670967	0.993307
# gen	nevals	avg	min	max
# 0  	250   	0.5	0.5	0.5
# 1  	218   	0.479272	0.0118976	0.754391
# 2  	204   	0.487489	0.0254844	0.754391
# 3  	212   	0.486143	0.0153435	0.932029
# 4  	224   	0.495961	0.0170554	0.971853
# 5  	219   	0.52265 	0.0132991	0.981156
# synthetic neighborhood class counts {0: 130, 1: 123, 2: 297}
# learning local decision tree
# retrieving explanation
# 30 / 36
# calculating feature values
# gen	nevals	avg     	min     	max
# 0  	250   	0.496654	0.496654	0.496654
# 1  	204   	0.51975 	0.00669974	0.993306
# 2  	219   	0.621854	0.00671513	0.993306
# 3  	208   	0.741262	0.00670245	0.993306
# 4  	205   	0.812156	0.00669332	0.993306
# 5  	215   	0.810725	0.00674907	0.993306
# gen	nevals	avg	min	max
# 0  	250   	0.5	0.5	0.5
# 1  	212   	0.549485	0.138626	0.992213
# 2  	215   	0.611088	0.0399052	0.993297
# 3  	210   	0.716979	0.0336268	0.993297
# 4  	213   	0.825965	0.0396711	0.993297
# 5  	215   	0.878397	0.0186765	0.9933
# synthetic neighborhood class counts {0: 236, 1: 207, 2: 107}
# learning local decision tree
# retrieving explanation
# 31 / 36
# calculating feature values
# gen	nevals	avg     	min     	max
# 0  	250   	0.496654	0.496654	0.496654
# 1  	222   	0.490737	0.00669577	0.993306
# 2  	218   	0.596713	0.00672792	0.993306
# 3  	213   	0.738736	0.00669714	0.993307
# 4  	222   	0.77807 	0.00669449	0.993307
# 5  	223   	0.804665	0.00678179	0.993307
# gen	nevals	avg	min	max
# 0  	250   	0.5	0.5	0.5
# 1  	207   	0.536801	0.0648846	0.991452
# 2  	212   	0.607519	0.0649262	0.993303
# 3  	213   	0.707668	0.0458436	0.993303
# 4  	207   	0.841164	0.227473 	0.993305
# 5  	219   	0.862909	0.00787577	0.993305
# synthetic neighborhood class counts {0: 240, 1: 191, 2: 119}
# learning local decision tree
# retrieving explanation
# 32 / 36
# calculating feature values
# gen	nevals	avg     	min     	max
# 0  	250   	0.496654	0.496654	0.496654
# 1  	212   	0.520606	0.0069481	0.993305
# 2  	206   	0.607692	0.00671645	0.993307
# 3  	217   	0.719526	0.00669811	0.993307
# 4  	208   	0.794014	0.00669354	0.993307
# 5  	217   	0.811326	0.00677045	0.993307
# gen	nevals	avg	min	max
# 0  	250   	0.5	0.5	0.5
# 1  	218   	0.559054	0.477857	0.990095
# 2  	210   	0.648814	0.459738	0.993071
# 3  	222   	0.755806	0.490306	0.99308
# 4  	216   	0.799719	0.494777	0.993085
# 5  	207   	0.861913	0.488007	0.993096
# synthetic neighborhood class counts {0: 216, 1: 236, 2: 98}
# learning local decision tree
# retrieving explanation
# 33 / 36
# calculating feature values
# gen	nevals	avg     	min     	max
# 0  	250   	0.496654	0.496654	0.496654
# 1  	203   	0.527556	0.00674518	0.993304
# 2  	206   	0.609944	0.00669432	0.993307
# 3  	200   	0.763826	0.0067229 	0.993307
# 4  	207   	0.773188	0.00670748	0.993307
# 5  	215   	0.815644	0.0067222 	0.993307
# gen	nevals	avg	min	max
# 0  	250   	0.5	0.5	0.5
# 1  	211   	0.564567	0.483448	0.992507
# 2  	212   	0.674173	0.460608	0.992527
# 3  	213   	0.749153	0.470387	0.992527
# 4  	205   	0.827359	0.467721	0.992588
# 5  	211   	0.884482	0.490868	0.992591
# synthetic neighborhood class counts {0: 238, 1: 229, 2: 83}
# learning local decision tree
# retrieving explanation
# 34 / 36
# calculating feature values
# gen	nevals	avg     	min     	max
# 0  	250   	0.496654	0.496654	0.496654
# 1  	217   	0.488696	0.00669435	0.993286
# 2  	216   	0.595908	0.00678403	0.993286
# 3  	213   	0.711187	0.00669407	0.993304
# 4  	222   	0.790034	0.00669818	0.993304
# 5  	208   	0.777689	0.00669532	0.993306
# gen	nevals	avg	min	max
# 0  	250   	0.5	0.5	0.5
# 1  	198   	0.533691	0.0117781	0.993216
# 2  	215   	0.615284	0.0132424	0.993103
# 3  	227   	0.726697	0.0075561	0.993306
# 4  	211   	0.831525	0.00840764	0.993306
# 5  	218   	0.879542	0.00695326	0.993306
# synthetic neighborhood class counts {0: 225, 1: 207, 2: 118}
# learning local decision tree
# retrieving explanation
# 35 / 36
# calculating feature values
# gen	nevals	avg     	min     	max
# 0  	250   	0.496654	0.496654	0.496654
# 1  	221   	0.516973	0.00669373	0.993307
# 2  	222   	0.633264	0.00669772	0.993307
# 3  	212   	0.757194	0.00669719	0.993307
# 4  	209   	0.790403	0.00672132	0.993307
# 5  	202   	0.825109	0.00683701	0.993307
# gen	nevals	avg	min	max
# 0  	250   	0.5	0.5	0.5
# 1  	211   	0.543711	0.475572	0.993031
# 2  	210   	0.611339	0.487563	0.993031
# 3  	217   	0.725057	0.473054	0.993218
# 4  	205   	0.808994	0.468697	0.993221
# 5  	228   	0.827584	0.479067	0.993228
# synthetic neighborhood class counts {0: 204, 1: 255, 2: 91}
# learning local decision tree
# retrieving explanation
# 36 / 36
# CPU times: user 8h 56min 9s, sys: 1h 58min 56s, total: 10h 55min 5s
# Wall time: 3h 37min 42s

# %%
# %%time
path_tree = parentdir + "/saved/cbf_resnet_20200603_002302/tree"
lasts_list_tree = load_multiple_lasts(
    path_tree, 
    verbose = True, 
    locator = False, 
    model = False, 
    transformer = True,
    load_sbgdt_model = True)
# Out:
# 1 / 36
# 2 / 36
# 3 / 36
# 4 / 36
# 5 / 36
# 6 / 36
# 7 / 36
# 8 / 36
# 9 / 36
# 10 / 36
# 11 / 36
# 12 / 36
# 13 / 36
# 14 / 36
# 15 / 36
# 16 / 36
# 17 / 36
# 18 / 36
# 19 / 36
# 20 / 36
# 21 / 36
# 22 / 36
# 23 / 36
# 24 / 36
# 25 / 36
# 26 / 36
# 27 / 36
# 28 / 36
# 29 / 36
# 30 / 36
# 31 / 36
# 32 / 36
# 33 / 36
# 34 / 36
# 35 / 36
# 36 / 36
# CPU times: user 5min 36s, sys: 3.97 s, total: 5min 40s
# Wall time: 5min 50s

# %%
path_notree = parentdir + "/saved/cbf_resnet_20200603_002302/notree"
lasts_list_notree = load_multiple_lasts(
    path_notree, 
    verbose = True, 
    locator = False, 
    model = False, 
    transformer = True,
    load_sbgdt_model = True)
# Out:
# 1 / 36
# 2 / 36
# 3 / 36
# 4 / 36
# 5 / 36
# 6 / 36
# 7 / 36
# 8 / 36
# 9 / 36
# 10 / 36
# 11 / 36
# 12 / 36
# 13 / 36
# 14 / 36
# 15 / 36
# 16 / 36
# 17 / 36
# 18 / 36
# 19 / 36
# 20 / 36
# 21 / 36
# 22 / 36
# 23 / 36
# 24 / 36
# 25 / 36
# 26 / 36
# 27 / 36
# 28 / 36
# 29 / 36
# 30 / 36
# 31 / 36
# 32 / 36
# 33 / 36
# 34 / 36
# 35 / 36
# 36 / 36

# %%
accuracy_tree = []
accuracy_notree = []

for i in range(len(lasts_list_tree)):
    accuracy_notree.append(lasts_list_notree[i].shapelet_explainer_fidelity())
    accuracy_tree.append(lasts_list_tree[i].shapelet_explainer_fidelity())
accuracy_tree = np.array(accuracy_tree)
accuracy_notree = np.array(accuracy_notree)
# Out:
# Shapelet explainer fidelity: 0.9636363636363636
# Shapelet explainer fidelity: 0.96
# Shapelet explainer fidelity: 0.9272727272727272
# Shapelet explainer fidelity: 0.8690909090909091
# Shapelet explainer fidelity: 0.9472727272727273
# Shapelet explainer fidelity: 0.9272727272727272
# Shapelet explainer fidelity: 0.9618181818181818
# Shapelet explainer fidelity: 0.8545454545454545
# Shapelet explainer fidelity: 0.9854545454545455
# Shapelet explainer fidelity: 0.9654545454545455
# Shapelet explainer fidelity: 0.9672727272727273
# Shapelet explainer fidelity: 0.7909090909090909
# Shapelet explainer fidelity: 0.9581818181818181
# Shapelet explainer fidelity: 0.8109090909090909
# Shapelet explainer fidelity: 0.9072727272727272
# Shapelet explainer fidelity: 0.9090909090909091
# Shapelet explainer fidelity: 0.9581818181818181
# Shapelet explainer fidelity: 0.9436363636363636
# Shapelet explainer fidelity: 0.9436363636363636
# Shapelet explainer fidelity: 0.8963636363636364
# Shapelet explainer fidelity: 0.9636363636363636
# Shapelet explainer fidelity: 0.6909090909090909
# Shapelet explainer fidelity: 0.96
# Shapelet explainer fidelity: 0.6636363636363637
# Shapelet explainer fidelity: 0.9581818181818181
# Shapelet explainer fidelity: 0.8781818181818182
# Shapelet explainer fidelity: 0.9745454545454545
# Shapelet explainer fidelity: 0.8563636363636363
# Shapelet explainer fidelity: 0.9545454545454546
# Shapelet explainer fidelity: 0.9272727272727272
# Shapelet explainer fidelity: 0.9436363636363636
# Shapelet explainer fidelity: 0.9272727272727272
# Shapelet explainer fidelity: 0.9681647940074907
# Shapelet explainer fidelity: 0.7790262172284644
# Shapelet explainer fidelity: 0.9581818181818181
# Shapelet explainer fidelity: 0.8018181818181818
# Shapelet explainer fidelity: 0.98
# Shapelet explainer fidelity: 0.9181818181818182
# Shapelet explainer fidelity: 0.9563636363636364
# Shapelet explainer fidelity: 0.94
# Shapelet explainer fidelity: 0.9672727272727273
# Shapelet explainer fidelity: 0.7890909090909091
# Shapelet explainer fidelity: 0.9672727272727273
# Shapelet explainer fidelity: 0.8418181818181818
# Shapelet explainer fidelity: 0.9581818181818181
# Shapelet explainer fidelity: 0.7381818181818182
# Shapelet explainer fidelity: 0.9163636363636364
# Shapelet explainer fidelity: 0.8763636363636363
# Shapelet explainer fidelity: 0.96
# Shapelet explainer fidelity: 0.7145454545454546
# Shapelet explainer fidelity: 0.9218181818181819
# Shapelet explainer fidelity: 0.850909090909091
# Shapelet explainer fidelity: 0.9727272727272728
# Shapelet explainer fidelity: 0.889090909090909
# Shapelet explainer fidelity: 0.96
# Shapelet explainer fidelity: 0.9272727272727272
# Shapelet explainer fidelity: 0.9781818181818182
# Shapelet explainer fidelity: 0.9327272727272727
# Shapelet explainer fidelity: 0.9745454545454545
# Shapelet explainer fidelity: 0.7927272727272727
# Shapelet explainer fidelity: 0.9672727272727273
# Shapelet explainer fidelity: 0.9581818181818181
# Shapelet explainer fidelity: 0.9454545454545454
# Shapelet explainer fidelity: 0.8672727272727273
# Shapelet explainer fidelity: 0.9581818181818181
# Shapelet explainer fidelity: 0.9454545454545454
# Shapelet explainer fidelity: 0.9581818181818181
# Shapelet explainer fidelity: 0.9527272727272728
# Shapelet explainer fidelity: 0.9454545454545454
# Shapelet explainer fidelity: 0.94
# Shapelet explainer fidelity: 0.9618181818181818
# Shapelet explainer fidelity: 0.9090909090909091

# %%
plt.boxplot(np.array([accuracy_tree, accuracy_notree]).T)
plt.xticks(ticks = [1,2], labels = ["tree", "notree"])
plt.show()
